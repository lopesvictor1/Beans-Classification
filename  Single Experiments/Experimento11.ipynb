# %% [markdown]
# Experimento 11 - Linear Interpolation Imputer, 3sigma, Z-Score, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               663
# Perimeter          677
# MajorAxisLength    689
# MinorAxisLength    651
# AspectRatio        666
# Eccentricity       659
# ConvexArea         631
# EquivDiameter      707
# Extent             684
# Solidity           646
# Roundness          647
# Compactness        688
# ShapeFactor1       711
# ShapeFactor2       716
# ShapeFactor3       714
# ShapeFactor4       657
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928              NaN     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799       NaN  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962       NaN   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099           NaN
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with Linear Interpolation
df_imputed = df.interpolate(method="nearest", order=3, limit=None,
                            limit_direction='both').ffill().bfill()
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       190.713136     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.730813  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.987813   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998385
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with 3sigma
from scipy import stats


print(f'Pre Outlier Shape: {df_imputed.shape}')
df_no_outliers = df_imputed.copy()

print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      upper = class_unique[feature].mean() + (3 * class_unique[feature].std())
      lower = class_unique[feature].mean() - (3 * class_unique[feature].std())
      excluded = pd.Series(class_unique[class_unique[feature] < lower].index)
      #print(excluded.values)
      df_no_outliers.drop(excluded.values, inplace = True, errors='ignore')

print(df_no_outliers.groupby('Class').count())
print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# Class
# 0      1262       1262             1262             1262         1262
# 1       498        498              498              498          498
# 2      1584       1584             1584             1584         1584
# 3      3408       3408             3408             3408         3408
# 4      1808       1808             1808             1808         1808
# 5      1917       1917             1917             1917         1917
# 6      2531       2531             2531             2531         2531
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  Roundness  \
# Class
# 0              1262        1262           1262    1262      1262       1262
# 1               498         498            498     498       498        498
# 2              1584        1584           1584    1584      1584       1584
# 3              3408        3408           3408    3408      3408       3408
# 4              1808        1808           1808    1808      1808       1808
# 5              1917        1917           1917    1917      1917       1917
# 6              2531        2531           2531    2531      2531       2531
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Class
# 0             1262          1262          1262          1262          1262
# 1              498           498           498           498           498
# 2             1584          1584          1584          1584          1584
# 3             3408          3408          3408          3408          3408
# 4             1808          1808          1808          1808          1808
# 5             1917          1917          1917          1917          1917
# 6             2531          2531          2531          2531          2531
# Pos Outlier Shape: (13008, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1262  1262      1262            1262            1262        1262
# BOMBAY     498   498       498             498             498         498
# CALI      1584  1584      1584            1584            1584        1584
# DERMASON  3408  3408      3408            3408            3408        3408
# HOROZ     1808  1808      1808            1808            1808        1808
# SEKER     1917  1917      1917            1917            1917        1917
# SIRA      2531  2531      2531            2531            2531        2531
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1262       1262          1262   1262     1262      1262
# BOMBAY            498        498           498    498      498       498
# CALI             1584       1584          1584   1584     1584      1584
# DERMASON         3408       3408          3408   3408     3408      3408
# HOROZ            1808       1808          1808   1808     1808      1808
# SEKER            1917       1917          1917   1917     1917      1917
# SIRA             2531       2531          2531   2531     2531      2531
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1262         1262         1262         1262         1262
# BOMBAY           498          498          498          498          498
# CALI            1584         1584         1584         1584         1584
# DERMASON        3408         3408         3408         3408         3408
# HOROZ           1808         1808         1808         1808         1808
# SEKER           1917         1917         1917         1917         1917
# SIRA            2531         2531         2531         2531         2531

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30279.0    634.927       212.560556       181.510182     1.171067
# 4      30477.0    670.033       211.050155       184.039050     1.146768
# ...        ...        ...              ...              ...          ...
# 13003  42097.0    759.696       288.721612       185.944705     1.552728
# 13004  42101.0    757.499       281.576392       190.713136     1.476439
# 13005  42139.0    759.321       281.539928       190.713136     1.472582
# 13006  42147.0    763.779       283.382636       190.275731     1.489326
# 13007  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 4          0.489478     30970.0     196.347702  0.762402  0.984081   0.853080
# ...             ...         ...            ...       ...       ...        ...
# 13003      0.765002     42508.0     231.515799  0.730813  0.990331   0.916603
# 13004      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13005      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13006      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13007      0.786693     42600.0     231.686223  0.788962  0.987813   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.923726      0.007020      0.003153      0.853270      0.999236
# 4         0.933374      0.006925      0.003242      0.871186      0.999049
# ...            ...           ...           ...           ...           ...
# 13003     0.801865      0.006858      0.001749      0.642988      0.998385
# 13004     0.822252      0.006688      0.001886      0.676099      0.998385
# 13005     0.822730      0.006681      0.001888      0.676884      0.996767
# 13006     0.817457      0.006724      0.001852      0.668237      0.995222
# 13007     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13003  DERMASON
# 13004  DERMASON
# 13005  DERMASON
# 13006  DERMASON
# 13007  DERMASON
#
# [13008 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.844005  -1.142756        -1.311222        -0.631975    -1.575377
# 1     -0.832419  -1.013138        -1.400646        -0.434565    -1.981565
# 2     -0.810341  -1.078155        -1.256914        -0.586395    -1.524433
# 3     -0.779617  -1.027588        -1.260017        -0.461887    -1.681667
# 4     -0.772850  -0.863474        -1.277665        -0.405450    -1.780528
# ...         ...        ...              ...              ...          ...
# 13003 -0.375724  -0.444318        -0.370130        -0.362921    -0.128838
# 13004 -0.375588  -0.454589        -0.453617        -0.256504    -0.439228
# 13005 -0.374289  -0.446071        -0.454043        -0.256504    -0.454923
# 13006 -0.374015  -0.425231        -0.432512        -0.266265    -0.386796
# 13007 -0.373605  -0.385692        -0.295104        -0.446387     0.144218
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.233693   -0.844491      -1.066525  0.280134  0.353505   1.440943
# 1         -3.759877   -0.829101      -1.047381  0.689628 -0.659467   0.204801
# 2         -2.090888   -0.811656      -1.011209  0.570023  0.537437   1.263729
# 3         -2.558900   -0.781009      -0.961527  0.520490  0.524621   1.194121
# 4         -2.900818   -0.768549      -0.961527  0.249062 -0.896126  -0.386404
# ...             ...         ...            ...       ...       ...        ...
# 13003      0.145695   -0.379978      -0.366583 -0.396224  0.739607   0.719666
# 13004     -0.178280   -0.380449      -0.366397  1.015964  0.849637   0.813904
# 13005     -0.196385   -0.377923      -0.364629 -0.414219  0.626418   0.751373
# 13006     -0.119095   -0.374623      -0.364258 -0.915592  0.080422   0.568239
# 13007      0.385533   -0.376879      -0.363700  0.791653  0.080422   0.228250
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         1.851416      0.686593      2.413438      1.944279      0.919606
# 1         2.511042      0.372430      3.114177      2.713809      0.840385
# 2         1.776770      0.608602      2.245874      1.859298      1.011967
# 3         2.020271      0.409296      2.422678      2.138088      1.057748
# 4         2.177390      0.324563      2.572874      2.320392      1.007271
# ...            ...           ...           ...           ...           ...
# 13003     0.035670      0.265430      0.060116     -0.001568      0.828219
# 13004     0.367689      0.113739      0.290267      0.335342      0.828219
# 13005     0.375466      0.107599      0.294367      0.343335      0.391582
# 13006     0.289604      0.145398      0.233361      0.255345     -0.025317
# 13007    -0.239038      0.392059     -0.123818     -0.273928      0.772728
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13003  DERMASON
# 13004  DERMASON
# 13005  DERMASON
# 13006  DERMASON
# 13007  DERMASON
#
# [13008 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}

y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 11')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 11
# Acurácia Média: 90.73%
# Precisão Média: 93.59%
# Revocação Média: 92.27%
# F1-Score Médio: 92.10%
