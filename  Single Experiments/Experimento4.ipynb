# %% [markdown]
# \Experimento 2 - KNN Imputer, 3sigma outlier detection, Z-Score normalization, MLP classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               668
# Perimeter          672
# MajorAxisLength    668
# MinorAxisLength    625
# AspectRatio        702
# Eccentricity       662
# ConvexArea         661
# EquivDiameter      688
# Extent             672
# Solidity           655
# Roundness          684
# Compactness        725
# ShapeFactor1       685
# ShapeFactor2       683
# ShapeFactor3       634
# ShapeFactor4       648
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796              NaN     1.097356
# 2      29380.0    624.110       212.826130       175.931143          NaN
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882              NaN     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716          NaN
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923       NaN   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727         NaN     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813        NaN
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0              NaN      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516           NaN      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606          NaN      0.006858           NaN      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457           NaN      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with KNN Imputer
from sklearn.impute import KNNImputer as knni

imputer = knni(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       171.220399     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.353299
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       164.309045     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.522373
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988850   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     28878.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.897435
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.829494      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.007770      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.816713      0.006858      0.001811      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006769      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with 3sigma
from scipy import stats


print(f'Pre Outlier Shape: {df_imputed.shape}')
df_no_outliers = df_imputed.copy()

print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      upper = class_unique[feature].mean() + (3 * class_unique[feature].std())
      lower = class_unique[feature].mean() - (3 * class_unique[feature].std())
      excluded = pd.Series(class_unique[class_unique[feature] < lower].index)
      #print(excluded.values)
      df_no_outliers.drop(excluded.values, inplace = True, errors='ignore')

print(df_no_outliers.groupby('Class').count())
print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# Class
# 0      1257       1257             1257             1257         1257
# 1       488        488              488              488          488
# 2      1577       1577             1577             1577         1577
# 3      3404       3404             3404             3404         3404
# 4      1808       1808             1808             1808         1808
# 5      1924       1924             1924             1924         1924
# 6      2531       2531             2531             2531         2531
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  Roundness  \
# Class
# 0              1257        1257           1257    1257      1257       1257
# 1               488         488            488     488       488        488
# 2              1577        1577           1577    1577      1577       1577
# 3              3404        3404           3404    3404      3404       3404
# 4              1808        1808           1808    1808      1808       1808
# 5              1924        1924           1924    1924      1924       1924
# 6              2531        2531           2531    2531      2531       2531
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Class
# 0             1257          1257          1257          1257          1257
# 1              488           488           488           488           488
# 2             1577          1577          1577          1577          1577
# 3             3404          3404          3404          3404          3404
# 4             1808          1808          1808          1808          1808
# 5             1924          1924          1924          1924          1924
# 6             2531          2531          2531          2531          2531
# Pos Outlier Shape: (12989, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1257  1257      1257            1257            1257        1257
# BOMBAY     488   488       488             488             488         488
# CALI      1577  1577      1577            1577            1577        1577
# DERMASON  3404  3404      3404            3404            3404        3404
# HOROZ     1808  1808      1808            1808            1808        1808
# SEKER     1924  1924      1924            1924            1924        1924
# SIRA      2531  2531      2531            2531            2531        2531
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1257       1257          1257   1257     1257      1257
# BOMBAY            488        488           488    488      488       488
# CALI             1577       1577          1577   1577     1577      1577
# DERMASON         3404       3404          3404   3404     3404      3404
# HOROZ            1808       1808          1808   1808     1808      1808
# SEKER            1924       1924          1924   1924     1924      1924
# SIRA             2531       2531          2531   2531     2531      2531
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1257         1257         1257         1257         1257
# BOMBAY           488          488          488          488          488
# CALI            1577         1577         1577         1577         1577
# DERMASON        3404         3404         3404         3404         3404
# HOROZ           1808         1808         1808         1808         1808
# SEKER           1924         1924         1924         1924         1924
# SIRA            2531         2531         2531         2531         2531

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       171.220399     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.353299
# 3      30279.0    634.927       212.560556       181.510182     1.171067
# 4      30477.0    670.033       211.050155       184.039050     1.146768
# ...        ...        ...              ...              ...          ...
# 12984  42097.0    759.696       288.721612       185.944705     1.552728
# 12985  42101.0    757.499       281.576392       190.713136     1.476439
# 12986  42139.0    759.321       281.539928       191.187979     1.472582
# 12987  42147.0    763.779       283.382636       190.275731     1.489326
# 12988  42159.0    772.237       295.142741       182.204716     1.522373
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988850   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     28878.0     193.410904  0.778113  0.989559   0.947849
# 3          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 4          0.489478     30970.0     196.988633  0.762402  0.984081   0.853080
# ...             ...         ...            ...       ...       ...        ...
# 12984      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 12985      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 12986      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 12987      0.741055     42667.0     231.653247  0.705389  0.987813   0.897435
# 12988      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.829494      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.923726      0.007020      0.003153      0.853270      0.999236
# 4         0.933374      0.006925      0.003242      0.871186      0.999049
# ...            ...           ...           ...           ...           ...
# 12984     0.816713      0.006858      0.001811      0.642988      0.998385
# 12985     0.822252      0.006688      0.001886      0.676099      0.998219
# 12986     0.822730      0.006681      0.001888      0.676884      0.996767
# 12987     0.817457      0.006769      0.001852      0.668237      0.995222
# 12988     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12984  DERMASON
# 12985  DERMASON
# 12986  DERMASON
# 12987  DERMASON
# 12988  DERMASON
#
# [12989 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.844497  -1.147079        -1.315015        -0.634006    -1.586864
# 1     -0.832858  -1.016526        -1.405015        -0.694107    -1.996646
# 2     -0.810679  -1.082012        -1.260357        -0.588004    -0.946107
# 3     -0.779814  -1.031080        -1.263480        -0.462343    -1.694094
# 4     -0.773016  -0.865784        -1.281241        -0.405384    -1.793830
# ...         ...        ...              ...              ...          ...
# 12984 -0.374072  -0.443605        -0.367859        -0.362462    -0.127529
# 12985 -0.373935  -0.453950        -0.451883        -0.255059    -0.440664
# 12986 -0.372630  -0.445371        -0.452312        -0.244364    -0.456498
# 12987 -0.372356  -0.424380        -0.430643        -0.264911    -0.387769
# 12988 -0.371944  -0.384556        -0.292349        -0.446700    -0.252125
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.252518   -0.845530      -1.070509  0.287679  0.359095   1.447889
# 1         -3.792211   -0.830065      -1.051208  0.706163 -0.681395   0.206331
# 2         -2.108450   -0.840014      -1.014739  0.583933  0.550044   1.269899
# 3         -2.580604   -0.781742      -0.964648  0.533312  0.536858   1.199986
# 4         -2.925548   -0.769221      -0.953716  0.255926 -0.924882  -0.387464
# ...             ...         ...            ...       ...       ...        ...
# 12984      0.147930   -0.378776      -0.364813 -0.742542  0.758047   0.723452
# 12985     -0.178912   -0.379249      -0.364626  1.039663  0.871251   0.818103
# 12986     -0.197177   -0.376711      -0.362844 -0.421916  0.641592   0.755298
# 12987     -0.119204   -0.373395      -0.362469 -0.934296  0.079842   0.388238
# 12988      0.389891   -0.375662      -0.361907  0.810428  0.574040   0.229883
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.494455      0.688853      2.424747      1.961241      0.935486
# 1         2.547665      0.372195      3.129329      2.737548      0.854801
# 2         1.803318      0.610243      2.256264      1.875512      1.029553
# 3         2.050160      0.409355      2.434038      2.156757      1.076180
# 4         2.209435      0.323949      2.585058      2.340667      1.024771
# ...            ...           ...           ...           ...           ...
# 12984     0.283448      0.264346      0.163734     -0.001742      0.842410
# 12985     0.374902      0.111452      0.289932      0.338134      0.796622
# 12986     0.382785      0.105263      0.294054      0.346198      0.397706
# 12987     0.295744      0.183727      0.232714      0.257433     -0.026897
# 12988    -0.240151      0.391980     -0.126424     -0.276501      0.785894
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12984  DERMASON
# 12985  DERMASON
# 12986  DERMASON
# 12987  DERMASON
# 12988  DERMASON
#
# [12989 rows x 17 columns]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_validate


x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
classifier = MLPClassifier(activation='logistic', solver='adam', alpha=1e-5, hidden_layer_sizes=(12, 3), random_state=1, verbose=True, learning_rate_init=0.3, tol=1e-3, max_iter=500)
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}


y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)
print('Experimento 4')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Iteration 1, loss = 1.22772010
# Iteration 2, loss = 0.78385609
# Iteration 3, loss = 0.43653881
# Iteration 4, loss = 0.32611633
# Iteration 5, loss = 0.30771800
# Iteration 6, loss = 0.28178239
# Iteration 7, loss = 0.27108935
# Iteration 8, loss = 0.25169378
# Iteration 9, loss = 0.23194078
# Iteration 10, loss = 0.21749134
# Iteration 11, loss = 0.22547751
# Iteration 12, loss = 0.24055746
# Iteration 13, loss = 0.20295229
# Iteration 14, loss = 0.22345963
# Iteration 15, loss = 0.19472270
# Iteration 16, loss = 0.19710992
# Iteration 17, loss = 0.20628418
# Iteration 18, loss = 0.19448985
# Iteration 19, loss = 0.20769628
# Iteration 20, loss = 0.19353469
# Iteration 21, loss = 0.20066129
# Iteration 22, loss = 0.19732676
# Iteration 23, loss = 0.18990822
# Iteration 24, loss = 0.20238996
# Iteration 25, loss = 0.19587849
# Iteration 26, loss = 0.18635434
# Iteration 27, loss = 0.19008162
# Iteration 28, loss = 0.18764158
# Iteration 29, loss = 0.17810481
# Iteration 30, loss = 0.20607785
# Iteration 31, loss = 0.17731643
# Iteration 32, loss = 0.17227246
# Iteration 33, loss = 0.19150869
# Iteration 34, loss = 0.18707001
# Iteration 35, loss = 0.20169130
# Iteration 36, loss = 0.18898401
# Iteration 37, loss = 0.18030807
# Iteration 38, loss = 0.17477407
# Iteration 39, loss = 0.17316419
# Iteration 40, loss = 0.17847534
# Iteration 41, loss = 0.19653724
# Iteration 42, loss = 0.23378478
# Iteration 43, loss = 0.19808712
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.20812646
# Iteration 2, loss = 0.70165153
# Iteration 3, loss = 0.56039728
# Iteration 4, loss = 0.51490594
# Iteration 5, loss = 0.50736063
# Iteration 6, loss = 0.52155661
# Iteration 7, loss = 0.49884061
# Iteration 8, loss = 0.49167851
# Iteration 9, loss = 0.50094264
# Iteration 10, loss = 0.41661599
# Iteration 11, loss = 0.33003648
# Iteration 12, loss = 0.27775284
# Iteration 13, loss = 0.33978863
# Iteration 14, loss = 0.32771323
# Iteration 15, loss = 0.29535569
# Iteration 16, loss = 0.30169318
# Iteration 17, loss = 0.29014709
# Iteration 18, loss = 0.25981857
# Iteration 19, loss = 0.27303137
# Iteration 20, loss = 0.24683039
# Iteration 21, loss = 0.24844154
# Iteration 22, loss = 0.25878056
# Iteration 23, loss = 0.23630883
# Iteration 24, loss = 0.24647042
# Iteration 25, loss = 0.26195505
# Iteration 26, loss = 0.25728887
# Iteration 27, loss = 0.26103434
# Iteration 28, loss = 0.24490861
# Iteration 29, loss = 0.24016769
# Iteration 30, loss = 0.24749213
# Iteration 31, loss = 0.24926866
# Iteration 32, loss = 0.25364606
# Iteration 33, loss = 0.24234654
# Iteration 34, loss = 0.24577190
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.21733374
# Iteration 2, loss = 0.71242358
# Iteration 3, loss = 0.48753629
# Iteration 4, loss = 0.40006295
# Iteration 5, loss = 0.36341484
# Iteration 6, loss = 0.31224021
# Iteration 7, loss = 0.29625845
# Iteration 8, loss = 0.27315304
# Iteration 9, loss = 0.28216811
# Iteration 10, loss = 0.29405096
# Iteration 11, loss = 0.29179929
# Iteration 12, loss = 0.27640737
# Iteration 13, loss = 0.26333674
# Iteration 14, loss = 0.27424594
# Iteration 15, loss = 0.27140655
# Iteration 16, loss = 0.26004293
# Iteration 17, loss = 0.26490807
# Iteration 18, loss = 0.28184391
# Iteration 19, loss = 0.26926361
# Iteration 20, loss = 0.24548498
# Iteration 21, loss = 0.24298486
# Iteration 22, loss = 0.25985240
# Iteration 23, loss = 0.24745333
# Iteration 24, loss = 0.26470246
# Iteration 25, loss = 0.25579540
# Iteration 26, loss = 0.26556522
# Iteration 27, loss = 0.27123294
# Iteration 28, loss = 0.26551110
# Iteration 29, loss = 0.23867572
# Iteration 30, loss = 0.23600313
# Iteration 31, loss = 0.22835822
# Iteration 32, loss = 0.24629650
# Iteration 33, loss = 0.24433967
# Iteration 34, loss = 0.24579789
# Iteration 35, loss = 0.26515515
# Iteration 36, loss = 0.24740452
# Iteration 37, loss = 0.25026618
# Iteration 38, loss = 0.26744633
# Iteration 39, loss = 0.25565971
# Iteration 40, loss = 0.24761459
# Iteration 41, loss = 0.24656182
# Iteration 42, loss = 0.24823098
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.23059888
# Iteration 2, loss = 0.73251495
# Iteration 3, loss = 0.46702576
# Iteration 4, loss = 0.39036071
# Iteration 5, loss = 0.38274553
# Iteration 6, loss = 0.36525348
# Iteration 7, loss = 0.34430858
# Iteration 8, loss = 0.30293285
# Iteration 9, loss = 0.28938322
# Iteration 10, loss = 0.29906474
# Iteration 11, loss = 0.31374970
# Iteration 12, loss = 0.29038787
# Iteration 13, loss = 0.27560963
# Iteration 14, loss = 0.28886487
# Iteration 15, loss = 0.26801258
# Iteration 16, loss = 0.28849868
# Iteration 17, loss = 0.28180066
# Iteration 18, loss = 0.27665171
# Iteration 19, loss = 0.28392604
# Iteration 20, loss = 0.25718435
# Iteration 21, loss = 0.28130737
# Iteration 22, loss = 0.25591561
# Iteration 23, loss = 0.25027576
# Iteration 24, loss = 0.24970723
# Iteration 25, loss = 0.24784320
# Iteration 26, loss = 0.25229339
# Iteration 27, loss = 0.26366236
# Iteration 28, loss = 0.25543410
# Iteration 29, loss = 0.24549176
# Iteration 30, loss = 0.26120100
# Iteration 31, loss = 0.26174496
# Iteration 32, loss = 0.25090440
# Iteration 33, loss = 0.24713908
# Iteration 34, loss = 0.24885248
# Iteration 35, loss = 0.26341522
# Iteration 36, loss = 0.27434873
# Iteration 37, loss = 0.25799938
# Iteration 38, loss = 0.24715735
# Iteration 39, loss = 0.24121349
# Iteration 40, loss = 0.23227078
# Iteration 41, loss = 0.23230450
# Iteration 42, loss = 0.25117117
# Iteration 43, loss = 0.24922406
# Iteration 44, loss = 0.25760420
# Iteration 45, loss = 0.26322623
# Iteration 46, loss = 0.25555614
# Iteration 47, loss = 0.25328914
# Iteration 48, loss = 0.25478518
# Iteration 49, loss = 0.25834506
# Iteration 50, loss = 0.26200232
# Iteration 51, loss = 0.26080289
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.23881587
# Iteration 2, loss = 0.80352653
# Iteration 3, loss = 0.52915672
# Iteration 4, loss = 0.40522106
# Iteration 5, loss = 0.33730472
# Iteration 6, loss = 0.29669959
# Iteration 7, loss = 0.30035649
# Iteration 8, loss = 0.28059714
# Iteration 9, loss = 0.27606282
# Iteration 10, loss = 0.27219374
# Iteration 11, loss = 0.28135983
# Iteration 12, loss = 0.28489665
# Iteration 13, loss = 0.26709974
# Iteration 14, loss = 0.29881666
# Iteration 15, loss = 0.28800606
# Iteration 16, loss = 0.27515862
# Iteration 17, loss = 0.28319914
# Iteration 18, loss = 0.27749595
# Iteration 19, loss = 0.29097263
# Iteration 20, loss = 0.27069457
# Iteration 21, loss = 0.27725583
# Iteration 22, loss = 0.30186159
# Iteration 23, loss = 0.27233066
# Iteration 24, loss = 0.28353589
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.24379610
# Iteration 2, loss = 0.69694558
# Iteration 3, loss = 0.48391783
# Iteration 4, loss = 0.42237621
# Iteration 5, loss = 0.35814756
# Iteration 6, loss = 0.31292325
# Iteration 7, loss = 0.30375533
# Iteration 8, loss = 0.26319575
# Iteration 9, loss = 0.27880588
# Iteration 10, loss = 0.26635698
# Iteration 11, loss = 0.27607876
# Iteration 12, loss = 0.27019679
# Iteration 13, loss = 0.26128279
# Iteration 14, loss = 0.26489354
# Iteration 15, loss = 0.28889772
# Iteration 16, loss = 0.26604958
# Iteration 17, loss = 0.24956417
# Iteration 18, loss = 0.26681791
# Iteration 19, loss = 0.26230567
# Iteration 20, loss = 0.27210703
# Iteration 21, loss = 0.25808976
# Iteration 22, loss = 0.28373459
# Iteration 23, loss = 0.26056348
# Iteration 24, loss = 0.27637898
# Iteration 25, loss = 0.25688553
# Iteration 26, loss = 0.25481431
# Iteration 27, loss = 0.25595766
# Iteration 28, loss = 0.26805245
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.22032616
# Iteration 2, loss = 0.55759720
# Iteration 3, loss = 0.32346888
# Iteration 4, loss = 0.29071506
# Iteration 5, loss = 0.28086431
# Iteration 6, loss = 0.28692136
# Iteration 7, loss = 0.29393754
# Iteration 8, loss = 0.27001643
# Iteration 9, loss = 0.26580872
# Iteration 10, loss = 0.26246047
# Iteration 11, loss = 0.27088565
# Iteration 12, loss = 0.26672680
# Iteration 13, loss = 0.25726183
# Iteration 14, loss = 0.26708857
# Iteration 15, loss = 0.25808386
# Iteration 16, loss = 0.25577606
# Iteration 17, loss = 0.25586188
# Iteration 18, loss = 0.25286892
# Iteration 19, loss = 0.27105079
# Iteration 20, loss = 0.26601113
# Iteration 21, loss = 0.26807205
# Iteration 22, loss = 0.27620196
# Iteration 23, loss = 0.28000233
# Iteration 24, loss = 0.24775984
# Iteration 25, loss = 0.25536131
# Iteration 26, loss = 0.25618870
# Iteration 27, loss = 0.25723600
# Iteration 28, loss = 0.24854384
# Iteration 29, loss = 0.24500647
# Iteration 30, loss = 0.25748120
# Iteration 31, loss = 0.26339177
# Iteration 32, loss = 0.26677739
# Iteration 33, loss = 0.26453924
# Iteration 34, loss = 0.25333096
# Iteration 35, loss = 0.25859155
# Iteration 36, loss = 0.24775151
# Iteration 37, loss = 0.25064324
# Iteration 38, loss = 0.25826238
# Iteration 39, loss = 0.25661820
# Iteration 40, loss = 0.25294963
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.18997961
# Iteration 2, loss = 0.54260448
# Iteration 3, loss = 0.33867375
# Iteration 4, loss = 0.28878916
# Iteration 5, loss = 0.28770035
# Iteration 6, loss = 0.28860812
# Iteration 7, loss = 0.27967236
# Iteration 8, loss = 0.28835229
# Iteration 9, loss = 0.28226716
# Iteration 10, loss = 0.29569797
# Iteration 11, loss = 0.30032581
# Iteration 12, loss = 0.27536059
# Iteration 13, loss = 0.27870085
# Iteration 14, loss = 0.28341065
# Iteration 15, loss = 0.28355861
# Iteration 16, loss = 0.27132481
# Iteration 17, loss = 0.27887389
# Iteration 18, loss = 0.26471044
# Iteration 19, loss = 0.26733675
# Iteration 20, loss = 0.24873047
# Iteration 21, loss = 0.25577962
# Iteration 22, loss = 0.27596147
# Iteration 23, loss = 0.26646989
# Iteration 24, loss = 0.29459808
# Iteration 25, loss = 0.26373144
# Iteration 26, loss = 0.25623168
# Iteration 27, loss = 0.27440385
# Iteration 28, loss = 0.25687530
# Iteration 29, loss = 0.25256097
# Iteration 30, loss = 0.25782089
# Iteration 31, loss = 0.26290085
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.28893972
# Iteration 2, loss = 0.73579970
# Iteration 3, loss = 0.47783589
# Iteration 4, loss = 0.38089875
# Iteration 5, loss = 0.35071271
# Iteration 6, loss = 0.30295784
# Iteration 7, loss = 0.29228620
# Iteration 8, loss = 0.28981843
# Iteration 9, loss = 0.28185193
# Iteration 10, loss = 0.30623372
# Iteration 11, loss = 0.30269962
# Iteration 12, loss = 0.27464734
# Iteration 13, loss = 0.26511647
# Iteration 14, loss = 0.29309652
# Iteration 15, loss = 0.26444184
# Iteration 16, loss = 0.26057785
# Iteration 17, loss = 0.24489631
# Iteration 18, loss = 0.25716371
# Iteration 19, loss = 0.25887929
# Iteration 20, loss = 0.25319600
# Iteration 21, loss = 0.30253849
# Iteration 22, loss = 0.28232902
# Iteration 23, loss = 0.26700310
# Iteration 24, loss = 0.25931975
# Iteration 25, loss = 0.24574991
# Iteration 26, loss = 0.24953376
# Iteration 27, loss = 0.25766925
# Iteration 28, loss = 0.25920072
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.09619870
# Iteration 2, loss = 0.50522379
# Iteration 3, loss = 0.37919228
# Iteration 4, loss = 0.30600492
# Iteration 5, loss = 0.23600911
# Iteration 6, loss = 0.20248511
# Iteration 7, loss = 0.19924259
# Iteration 8, loss = 0.18858163
# Iteration 9, loss = 0.19989480
# Iteration 10, loss = 0.19201424
# Iteration 11, loss = 0.18063347
# Iteration 12, loss = 0.19756575
# Iteration 13, loss = 0.19185134
# Iteration 14, loss = 0.19039506
# Iteration 15, loss = 0.19795278
# Iteration 16, loss = 0.19157586
# Iteration 17, loss = 0.18472169
# Iteration 18, loss = 0.17824383
# Iteration 19, loss = 0.18041244
# Iteration 20, loss = 0.18153931
# Iteration 21, loss = 0.18200749
# Iteration 22, loss = 0.17363687
# Iteration 23, loss = 0.17799609
# Iteration 24, loss = 0.18530901
# Iteration 25, loss = 0.18419979
# Iteration 26, loss = 0.17130280
# Iteration 27, loss = 0.17859057
# Iteration 28, loss = 0.18581561
# Iteration 29, loss = 0.17572678
# Iteration 30, loss = 0.19205204
# Iteration 31, loss = 0.18051851
# Iteration 32, loss = 0.18535620
# Iteration 33, loss = 0.17947570
# Iteration 34, loss = 0.17736419
# Iteration 35, loss = 0.18595306
# Iteration 36, loss = 0.17684984
# Iteration 37, loss = 0.17748786
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Experimento 4
# Acurácia Média: 87.90%
# Precisão Média: 90.96%
# Revocação Média: 89.74%
# F1-Score Médio: 89.27%
