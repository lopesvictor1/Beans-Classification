# %% [markdown]
# Experimento 5 - KNN Imputer, MAD outlier detection, min max normalization, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               650
# Perimeter          671
# MajorAxisLength    710
# MinorAxisLength    651
# AspectRatio        680
# Eccentricity       663
# ConvexArea         694
# EquivDiameter      647
# Extent             687
# Solidity           690
# Roundness          653
# Compactness        688
# ShapeFactor1       635
# ShapeFactor2       661
# ShapeFactor3       678
# ShapeFactor4       662
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136          NaN
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237              NaN       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113       NaN   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0            NaN  0.705389  0.987813   0.907906
# 13610      0.786693         NaN     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with KNN Imputer
from sklearn.impute import KNNImputer as knni

imputer = knni(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.548883
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       289.813329       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989025   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     230.498566  0.705389  0.987813   0.907906
# 13610      0.786693     42204.6     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with MAD
from scipy import stats

print(f'Pre Outlier Shape: {df_imputed.shape}')

df_no_outliers = df_imputed.copy()
print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      mad = 1.4826 * np.median(np.absolute(class_unique[feature] - class_unique[feature].median()))
      upper = class_unique[feature].median() + (3 * mad)
      lower = class_unique[feature].median() - (3 * mad)
      excluded_lower = pd.Series(class_unique[class_unique[feature] < lower].index)
      excluded_upper = pd.Series(class_unique[class_unique[feature] > upper].index)
      df_no_outliers.drop(excluded_lower.values, inplace = True, errors='ignore')
      df_no_outliers.drop(excluded_upper.values, inplace = True, errors='ignore')


print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
# Pos Outlier Shape: (12035, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1197  1197      1197            1197            1197        1197
# BOMBAY     406   406       406             406             406         406
# CALI      1492  1492      1492            1492            1492        1492
# DERMASON  3206  3206      3206            3206            3206        3206
# HOROZ     1573  1573      1573            1573            1573        1573
# SEKER     1756  1756      1756            1756            1756        1756
# SIRA      2405  2405      2405            2405            2405        2405
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1197       1197          1197   1197     1197      1197
# BOMBAY            406        406           406    406      406       406
# CALI             1492       1492          1492   1492     1492      1492
# DERMASON         3206       3206          3206   3206     3206      3206
# HOROZ            1573       1573          1573   1573     1573      1573
# SEKER            1756       1756          1756   1756     1756      1756
# SIRA             2405       2405          2405   2405     2405      2405
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1197         1197         1197         1197         1197
# BOMBAY           406          406          406          406          406
# CALI            1492         1492         1492         1492         1492
# DERMASON        3206         3206         3206         3206         3206
# HOROZ           1573         1573         1573         1573         1573
# SEKER           1756         1756         1756         1756         1756
# SIRA            2405         2405         2405         2405         2405

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      29380.0    624.110       212.826130       175.931143     1.209713
# 2      30279.0    634.927       212.560556       181.510182     1.171067
# 3      30519.0    629.727       212.996755       182.737204     1.165591
# 4      30685.0    635.681       213.534145       183.157146     1.165852
# ...        ...        ...              ...              ...          ...
# 12030  42097.0    759.696       288.721612       185.944705     1.552728
# 12031  42101.0    757.499       281.576392       190.713136     1.548883
# 12032  42139.0    759.321       281.539928       191.187979     1.472582
# 12033  42147.0    763.779       283.382636       190.275731     1.489326
# 12034  42159.0    772.237       289.813329       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.562727     29690.0     193.410904  0.778113  0.989025   0.947849
# 2          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 3          0.513760     30847.0     197.124320  0.770682  0.989367   0.967109
# 4          0.514081     31044.0     197.659696  0.771561  0.988436   0.954240
# ...             ...         ...            ...       ...       ...        ...
# 12030      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 12031      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 12032      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 12033      0.741055     42667.0     230.498566  0.705389  0.987813   0.907906
# 12034      0.786693     42204.6     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.908774      0.007244      0.003048      0.825871      0.999066
# 2         0.923726      0.007020      0.003153      0.853270      0.999236
# 3         0.925480      0.006979      0.003158      0.856514      0.998345
# 4         0.925658      0.006959      0.003152      0.856844      0.998953
# ...            ...           ...           ...           ...           ...
# 12030     0.801865      0.006858      0.001749      0.642988      0.998385
# 12031     0.822252      0.006688      0.001886      0.676099      0.998219
# 12032     0.822730      0.006681      0.001888      0.676884      0.996767
# 12033     0.817457      0.006724      0.001852      0.668237      0.995222
# 12034     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12030  DERMASON
# 12031  DERMASON
# 12032  DERMASON
# 12033  DERMASON
# 12034  DERMASON
#
# [12035 rows x 17 columns]

# %%
#Normalization with min max
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      0.037183   0.061112         0.044319         0.130253     0.100108
# 1      0.041776   0.071006         0.052701         0.136911     0.109608
# 2      0.045967   0.078751         0.052222         0.155099     0.080287
# 3      0.047086   0.075028         0.053009         0.159099     0.076132
# 4      0.047860   0.079290         0.053978         0.160468     0.076331
# ...         ...        ...              ...              ...          ...
# 12030  0.101069   0.168078         0.189562         0.169555     0.369861
# 12031  0.101087   0.166505         0.176677         0.185100     0.366943
# 12032  0.101264   0.167810         0.176612         0.186648     0.309052
# 12033  0.101302   0.171002         0.179934         0.183674     0.321756
# 12034  0.101358   0.177057         0.191531         0.157363     0.420780
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.300614    0.036507       0.074402  0.671024  0.758074   0.898371
# 1          0.325828    0.040939       0.082821  0.716671  0.765107   0.866700
# 2          0.243193    0.045075       0.090382  0.708871  0.785244   0.854259
# 3          0.230228    0.046198       0.092382  0.692766  0.779305   0.926634
# 4          0.230855    0.047094       0.093760  0.695596  0.740610   0.886586
# ...             ...         ...            ...       ...       ...        ...
# 12030      0.720731    0.099206       0.180930  0.512286  0.819381   0.769465
# 12031      0.663528    0.099142       0.180958  0.786890  0.836852   0.786307
# 12032      0.660332    0.099483       0.181227  0.561689  0.801408   0.775132
# 12033      0.673978    0.099929       0.178311  0.482741  0.714713   0.742402
# 12034      0.763078    0.097827       0.181369  0.751569  0.790983   0.681639
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.829495      0.669818      0.904027      0.801180      0.948254
# 1         0.815308      0.656551      0.868833      0.785162      0.965812
# 2         0.861587      0.622647      0.905967      0.837713      0.974516
# 3         0.867017      0.616450      0.907914      0.843935      0.928794
# 4         0.867568      0.613384      0.905533      0.844567      0.960007
# ...            ...           ...           ...           ...           ...
# 12030     0.484398      0.598174      0.409760      0.434398      0.930881
# 12031     0.547501      0.572370      0.458098      0.497904      0.922335
# 12032     0.548979      0.571325      0.458959      0.499410      0.847875
# 12033     0.532660      0.577755      0.446146      0.482825      0.768620
# 12034     0.432187      0.619715      0.371128      0.383059      0.920332
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12030  DERMASON
# 12031  DERMASON
# 12032  DERMASON
# 12033  DERMASON
# 12034  DERMASON
#
# [12035 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}


y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 5')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 5
# Acurácia Média: 91.60%
# Precisão Média: 94.55%
# Revocação Média: 93.21%
# F1-Score Médio: 93.04%
