# %% [markdown]
# Experimento 1 - KNN Imputer, 3sigma, min max normalization, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               709
# Perimeter          727
# MajorAxisLength    662
# MinorAxisLength    694
# AspectRatio        631
# Eccentricity       653
# ConvexArea         664
# EquivDiameter      617
# Extent             686
# Solidity           625
# Roundness          645
# Compactness        648
# ShapeFactor1       666
# ShapeFactor2       658
# ShapeFactor3       685
# ShapeFactor4       634
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0            NaN  0.783968  0.984986   0.887034
# 2          0.562727         NaN     193.410904  0.778113  0.989559        NaN
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0            NaN  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610           NaN     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329           NaN      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609          NaN      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997           NaN      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with KNN Imputer
from sklearn.impute import KNNImputer as knni

imputer = knni(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     195.518255  0.783968  0.984986   0.887034
# 2          0.562727     30100.4     193.410904  0.778113  0.989559   0.943176
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     194.649066  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.747250     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007499      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817453      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.006814      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with 3sigma
from scipy import stats


print(f'Pre Outlier Shape: {df_imputed.shape}')
df_no_outliers = df_imputed.copy()

print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      upper = class_unique[feature].mean() + (3 * class_unique[feature].std())
      lower = class_unique[feature].mean() - (3 * class_unique[feature].std())
      excluded = pd.Series(class_unique[class_unique[feature] < lower].index)
      #print(excluded.values)
      df_no_outliers.drop(excluded.values, inplace = True, errors='ignore')

print(df_no_outliers.groupby('Class').count())
print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# Class
# 0      1262       1262             1262             1262         1262
# 1       482        482              482              482          482
# 2      1578       1578             1578             1578         1578
# 3      3411       3411             3411             3411         3411
# 4      1800       1800             1800             1800         1800
# 5      1918       1918             1918             1918         1918
# 6      2536       2536             2536             2536         2536
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  Roundness  \
# Class
# 0              1262        1262           1262    1262      1262       1262
# 1               482         482            482     482       482        482
# 2              1578        1578           1578    1578      1578       1578
# 3              3411        3411           3411    3411      3411       3411
# 4              1800        1800           1800    1800      1800       1800
# 5              1918        1918           1918    1918      1918       1918
# 6              2536        2536           2536    2536      2536       2536
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Class
# 0             1262          1262          1262          1262          1262
# 1              482           482           482           482           482
# 2             1578          1578          1578          1578          1578
# 3             3411          3411          3411          3411          3411
# 4             1800          1800          1800          1800          1800
# 5             1918          1918          1918          1918          1918
# 6             2536          2536          2536          2536          2536
# Pos Outlier Shape: (12987, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1262  1262      1262            1262            1262        1262
# BOMBAY     482   482       482             482             482         482
# CALI      1578  1578      1578            1578            1578        1578
# DERMASON  3411  3411      3411            3411            3411        3411
# HOROZ     1800  1800      1800            1800            1800        1800
# SEKER     1918  1918      1918            1918            1918        1918
# SIRA      2536  2536      2536            2536            2536        2536
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1262       1262          1262   1262     1262      1262
# BOMBAY            482        482           482    482      482       482
# CALI             1578       1578          1578   1578     1578      1578
# DERMASON         3411       3411          3411   3411     3411      3411
# HOROZ            1800       1800          1800   1800     1800      1800
# SEKER            1918       1918          1918   1918     1918      1918
# SIRA             2536       2536          2536   2536     2536      2536
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1262         1262         1262         1262         1262
# BOMBAY           482          482          482          482          482
# CALI            1578         1578         1578         1578         1578
# DERMASON        3411         3411         3411         3411         3411
# HOROZ           1800         1800         1800         1800         1800
# SEKER           1918         1918         1918         1918         1918
# SIRA            2536         2536         2536         2536         2536

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30279.0    634.927       212.560556       181.510182     1.171067
# 4      30477.0    670.033       211.050155       184.039050     1.146768
# ...        ...        ...              ...              ...          ...
# 12982  42097.0    759.696       288.721612       185.944705     1.552728
# 12983  42101.0    757.499       281.576392       190.713136     1.476439
# 12984  42139.0    759.321       281.539928       191.187979     1.472582
# 12985  42147.0    763.779       283.382636       190.275731     1.489326
# 12986  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     195.518255  0.783968  0.984986   0.887034
# 2          0.562727     30100.4     193.410904  0.778113  0.989559   0.943176
# 3          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 4          0.489478     30970.0     196.988633  0.762402  0.984081   0.853080
# ...             ...         ...            ...       ...       ...        ...
# 12982      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 12983      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 12984      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 12985      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 12986      0.747250     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.923726      0.007020      0.003153      0.853270      0.999236
# 4         0.933374      0.006925      0.003242      0.871186      0.999049
# ...            ...           ...           ...           ...           ...
# 12982     0.801865      0.006858      0.001749      0.642988      0.998385
# 12983     0.822252      0.006688      0.001886      0.676099      0.998219
# 12984     0.822730      0.006681      0.001888      0.676884      0.996767
# 12985     0.817453      0.006724      0.001852      0.668237      0.995222
# 12986     0.784997      0.006814      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12982  DERMASON
# 12983  DERMASON
# 12984  DERMASON
# 12985  DERMASON
# 12986  DERMASON
#
# [12987 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.851935  -1.152999        -1.321553        -0.638714    -1.582862
# 1     -0.840179  -1.021505        -1.412167        -0.438051    -1.992519
# 2     -0.817777  -1.087463        -1.266521        -0.592382    -1.531483
# 3     -0.786601  -1.036164        -1.269665        -0.465822    -1.690060
# 4     -0.779734  -0.869676        -1.287548        -0.408455    -1.789765
# ...         ...        ...              ...              ...          ...
# 12982 -0.376771  -0.444454        -0.367931        -0.365226    -0.123970
# 12983 -0.376632  -0.454873        -0.452529        -0.257054    -0.437010
# 12984 -0.375314  -0.446232        -0.452961        -0.246283    -0.452839
# 12985 -0.375037  -0.425091        -0.431143        -0.266977    -0.384131
# 12986 -0.374621  -0.384979        -0.291906        -0.450067     0.151418
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.251788   -0.848832      -1.075061  0.276006  0.353677   1.445473
# 1         -3.791886   -0.833262      -0.983001  0.694871 -0.685480   0.203031
# 2         -2.107682   -0.801630      -1.019080  0.572530  0.542364   1.185572
# 3         -2.579961   -0.784608      -0.968800  0.521863  0.529216   1.197394
# 4         -2.924995   -0.772002      -0.957827  0.244223 -0.928256  -0.391187
# ...             ...         ...            ...       ...       ...        ...
# 12982      0.149292   -0.378890      -0.366704 -0.755154  0.749760   0.720520
# 12983     -0.177636   -0.379367      -0.366516  1.028675  0.862634   0.815238
# 12984     -0.195907   -0.376811      -0.364727 -0.434237  0.633644   0.752389
# 12985     -0.117913   -0.373472      -0.364351 -0.947084  0.073535   0.568322
# 12986     -0.048790   -0.375755      -0.363786  0.799231  0.566290   0.226600
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         1.867155      0.689816      2.422183      1.957142      0.936762
# 1         2.533671      0.372205      3.127256      2.733993      0.855703
# 2         1.791729      0.610969      2.253583      1.871352      1.031265
# 3         2.037773      0.409476      2.431481      2.152795      1.078109
# 4         2.196533      0.323813      2.582606      2.336834      1.026461
# ...            ...           ...           ...           ...           ...
# 12982     0.032441      0.264030      0.054307     -0.007220      0.843254
# 12983     0.367928      0.110675      0.285881      0.332895      0.797253
# 12984     0.375786      0.104468      0.290007      0.340964      0.396486
# 12985     0.288952      0.142682      0.228623      0.252137     -0.030086
# 12986    -0.245137      0.223932     -0.130764     -0.282172      0.786475
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12982  DERMASON
# 12983  DERMASON
# 12984  DERMASON
# 12985  DERMASON
# 12986  DERMASON
#
# [12987 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}

y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 3')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 3
# Acurácia Média: 90.01%
# Precisão Média: 92.97%
# Revocação Média: 91.60%
# F1-Score Médio: 91.44%
