# %% [markdown]
# Experimento 12 - Linear Interpolation Imputer, 3sigma outlier detection, Z-Score normalization, MLP classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               668
# Perimeter          689
# MajorAxisLength    686
# MinorAxisLength    695
# AspectRatio        652
# Eccentricity       620
# ConvexArea         678
# EquivDiameter      681
# Extent             689
# Solidity           671
# Roundness          713
# Compactness        667
# ShapeFactor1       676
# ShapeFactor2       678
# ShapeFactor3       732
# ShapeFactor4       675
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143          NaN
# 3      30008.0        NaN       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321              NaN       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741              NaN     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986        NaN
# 2          0.562727     29690.0            NaN  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0            NaN  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0            NaN  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899        NaN
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147           NaN      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774           NaN      0.003048      0.825871      0.999066
# 3              NaN      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665           NaN      0.999166
# ...            ...           ...           ...           ...           ...
# 13606          NaN      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099           NaN
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with Linear Interpolation
df_imputed = df.interpolate(method="nearest", order=3, limit=None,
                            limit_direction='both').ffill().bfill()
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.097356
# 3      30008.0    624.110       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.576392       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       190.275731     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.958027
# 2          0.562727     29690.0     191.272751  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.467062  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.515799  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.922015
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.909851      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.006979      0.003048      0.825871      0.999066
# 3         0.908774      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.861794      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.836460      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998385
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with 3sigma
from scipy import stats


print(f'Pre Outlier Shape: {df_imputed.shape}')
df_no_outliers = df_imputed.copy()

print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      upper = class_unique[feature].mean() + (3 * class_unique[feature].std())
      lower = class_unique[feature].mean() - (3 * class_unique[feature].std())
      excluded = pd.Series(class_unique[class_unique[feature] < lower].index)
      #print(excluded.values)
      df_no_outliers.drop(excluded.values, inplace = True, errors='ignore')

print(df_no_outliers.groupby('Class').count())
print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# Class
# 0      1261       1261             1261             1261         1261
# 1       497        497              497              497          497
# 2      1578       1578             1578             1578         1578
# 3      3415       3415             3415             3415         3415
# 4      1807       1807             1807             1807         1807
# 5      1919       1919             1919             1919         1919
# 6      2531       2531             2531             2531         2531
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  Roundness  \
# Class
# 0              1261        1261           1261    1261      1261       1261
# 1               497         497            497     497       497        497
# 2              1578        1578           1578    1578      1578       1578
# 3              3415        3415           3415    3415      3415       3415
# 4              1807        1807           1807    1807      1807       1807
# 5              1919        1919           1919    1919      1919       1919
# 6              2531        2531           2531    2531      2531       2531
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Class
# 0             1261          1261          1261          1261          1261
# 1              497           497           497           497           497
# 2             1578          1578          1578          1578          1578
# 3             3415          3415          3415          3415          3415
# 4             1807          1807          1807          1807          1807
# 5             1919          1919          1919          1919          1919
# 6             2531          2531          2531          2531          2531
# Pos Outlier Shape: (13008, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1261  1261      1261            1261            1261        1261
# BOMBAY     497   497       497             497             497         497
# CALI      1578  1578      1578            1578            1578        1578
# DERMASON  3415  3415      3415            3415            3415        3415
# HOROZ     1807  1807      1807            1807            1807        1807
# SEKER     1919  1919      1919            1919            1919        1919
# SIRA      2531  2531      2531            2531            2531        2531
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1261       1261          1261   1261     1261      1261
# BOMBAY            497        497           497    497      497       497
# CALI             1578       1578          1578   1578     1578      1578
# DERMASON         3415       3415          3415   3415     3415      3415
# HOROZ            1807       1807          1807   1807     1807      1807
# SEKER            1919       1919          1919   1919     1919      1919
# SIRA             2531       2531          2531   2531     2531      2531
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1261         1261         1261         1261         1261
# BOMBAY           497          497          497          497          497
# CALI            1578         1578         1578         1578         1578
# DERMASON        3415         3415         3415         3415         3415
# HOROZ           1807         1807         1807         1807         1807
# SEKER           1919         1919         1919         1919         1919
# SIRA            2531         2531         2531         2531         2531

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.097356
# 3      30279.0    634.927       212.560556       181.510182     1.171067
# 4      30477.0    670.033       211.050155       184.039050     1.146768
# ...        ...        ...              ...              ...          ...
# 13003  42097.0    759.696       288.721612       185.944705     1.552728
# 13004  42101.0    757.499       281.576392       190.713136     1.476439
# 13005  42139.0    759.321       281.576392       191.187979     1.472582
# 13006  42147.0    763.779       283.382636       190.275731     1.489326
# 13007  42159.0    772.237       295.142741       190.275731     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.958027
# 2          0.562727     29690.0     191.272751  0.778113  0.989559   0.947849
# 3          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 4          0.489478     30970.0     196.988633  0.762402  0.984081   0.853080
# ...             ...         ...            ...       ...       ...        ...
# 13003      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13004      0.735702     42494.0     231.515799  0.799943  0.990752   0.922015
# 13005      0.734065     42569.0     231.631261  0.729932  0.989899   0.922015
# 13006      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13007      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.909851      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.006979      0.003048      0.825871      0.999066
# 3         0.923726      0.007020      0.003153      0.853270      0.999236
# 4         0.933374      0.006925      0.003242      0.871186      0.999049
# ...            ...           ...           ...           ...           ...
# 13003     0.836460      0.006858      0.001749      0.642988      0.998385
# 13004     0.822252      0.006688      0.001886      0.676099      0.998385
# 13005     0.822730      0.006681      0.001888      0.676884      0.996767
# 13006     0.817457      0.006724      0.001852      0.668237      0.995222
# 13007     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13003  DERMASON
# 13004  DERMASON
# 13005  DERMASON
# 13006  DERMASON
# 13007  DERMASON
#
# [13008 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.843317  -1.141615        -1.308972        -0.631972    -1.568610
# 1     -0.831725  -1.011927        -1.398323        -0.434550    -1.973414
# 2     -0.809635  -1.076980        -1.254707        -0.586389    -1.973414
# 3     -0.778893  -1.026385        -1.257808        -0.461873    -1.674538
# 4     -0.772123  -0.862183        -1.275441        -0.405432    -1.773062
# ...         ...        ...              ...              ...          ...
# 13003 -0.374775  -0.442800        -0.368640        -0.362901    -0.127002
# 13004 -0.374639  -0.453076        -0.452060        -0.256477    -0.436333
# 13005 -0.373339  -0.444554        -0.452060        -0.245879    -0.451975
# 13006 -0.373066  -0.423703        -0.430972        -0.266239    -0.384081
# 13007 -0.372655  -0.384142        -0.293675        -0.266239     0.145124
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.223043   -0.843951      -1.065581  0.278140  0.351222   1.442120
# 1         -3.744892   -0.828548      -1.046429  0.688392 -0.671623   1.442120
# 2         -2.080644   -0.811090      -1.046429  0.568566  0.536948   1.264534
# 3         -2.547327   -0.780419      -0.960542  0.518941  0.524006   1.194780
# 4         -2.888273   -0.767948      -0.949695  0.247011 -0.910589  -0.389064
# ...             ...         ...            ...       ...       ...        ...
# 13003      0.149587   -0.379071      -0.365363 -0.731818  0.741088   0.719329
# 13004     -0.173467   -0.379543      -0.365363  1.015332  0.852190   0.813765
# 13005     -0.191521   -0.377015      -0.363409 -0.417499  0.626795   0.813765
# 13006     -0.114451   -0.373712      -0.363037 -0.919801  0.075478   0.567584
# 13007      0.388745   -0.375971      -0.362479  0.790606  0.560498   0.226881
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         1.855382      0.684811      2.411027      2.711268      0.920668
# 1         2.516391      0.370591      3.111578      2.711268      0.840464
# 2         1.780579      0.370591      2.243508      1.857504      1.014176
# 3         2.024591      0.407464      2.420265      2.136051      1.060525
# 4         2.182039      0.322716      2.570421      2.318196      1.009421
# ...            ...           ...           ...           ...           ...
# 13003     0.600416      0.263571      0.058339     -0.001735      0.828146
# 13004     0.368542      0.111853      0.288427      0.334880      0.828146
# 13005     0.376336      0.105712      0.292526      0.342866      0.386089
# 13006     0.290293      0.143518      0.231537      0.254953     -0.035986
# 13007    -0.239457      0.390223     -0.125546     -0.273857      0.771967
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13003  DERMASON
# 13004  DERMASON
# 13005  DERMASON
# 13006  DERMASON
# 13007  DERMASON
#
# [13008 rows x 17 columns]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_validate


x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
classifier = MLPClassifier(activation='logistic', solver='adam', alpha=1e-5, hidden_layer_sizes=(12, 3), random_state=1, verbose=True, learning_rate_init=0.3, tol=1e-3, max_iter=500)
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}


y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)
print('Experimento 12')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Iteration 1, loss = 1.19385607
# Iteration 2, loss = 0.85826310
# Iteration 3, loss = 0.56864499
# Iteration 4, loss = 0.50971298
# Iteration 5, loss = 0.33920637
# Iteration 6, loss = 0.22458447
# Iteration 7, loss = 0.19126820
# Iteration 8, loss = 0.19883450
# Iteration 9, loss = 0.18849355
# Iteration 10, loss = 0.18589094
# Iteration 11, loss = 0.18930835
# Iteration 12, loss = 0.16973104
# Iteration 13, loss = 0.16631811
# Iteration 14, loss = 0.17018963
# Iteration 15, loss = 0.16689053
# Iteration 16, loss = 0.17376167
# Iteration 17, loss = 0.16673802
# Iteration 18, loss = 0.19233249
# Iteration 19, loss = 0.18215390
# Iteration 20, loss = 0.16405820
# Iteration 21, loss = 0.19418281
# Iteration 22, loss = 0.16354400
# Iteration 23, loss = 0.16839186
# Iteration 24, loss = 0.20378246
# Iteration 25, loss = 0.17844230
# Iteration 26, loss = 0.17467153
# Iteration 27, loss = 0.17343411
# Iteration 28, loss = 0.17845131
# Iteration 29, loss = 0.16844675
# Iteration 30, loss = 0.15405575
# Iteration 31, loss = 0.16250191
# Iteration 32, loss = 0.20736186
# Iteration 33, loss = 0.18897094
# Iteration 34, loss = 0.18600316
# Iteration 35, loss = 0.15381369
# Iteration 36, loss = 0.15096213
# Iteration 37, loss = 0.15792927
# Iteration 38, loss = 0.15316516
# Iteration 39, loss = 0.15785973
# Iteration 40, loss = 0.14934996
# Iteration 41, loss = 0.15702481
# Iteration 42, loss = 0.15932870
# Iteration 43, loss = 0.14246782
# Iteration 44, loss = 0.16154136
# Iteration 45, loss = 0.18206396
# Iteration 46, loss = 0.16417777
# Iteration 47, loss = 0.15791126
# Iteration 48, loss = 0.16401163
# Iteration 49, loss = 0.15946668
# Iteration 50, loss = 0.15401441
# Iteration 51, loss = 0.16215918
# Iteration 52, loss = 0.18020554
# Iteration 53, loss = 0.19994465
# Iteration 54, loss = 0.18564191
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.19129821
# Iteration 2, loss = 0.67766024
# Iteration 3, loss = 0.41420304
# Iteration 4, loss = 0.36642521
# Iteration 5, loss = 0.33995704
# Iteration 6, loss = 0.33209933
# Iteration 7, loss = 0.31700581
# Iteration 8, loss = 0.32601861
# Iteration 9, loss = 0.29584384
# Iteration 10, loss = 0.29413663
# Iteration 11, loss = 0.27507075
# Iteration 12, loss = 0.26088597
# Iteration 13, loss = 0.27505978
# Iteration 14, loss = 0.26844535
# Iteration 15, loss = 0.25178733
# Iteration 16, loss = 0.24466923
# Iteration 17, loss = 0.22819142
# Iteration 18, loss = 0.22407812
# Iteration 19, loss = 0.23139596
# Iteration 20, loss = 0.23409486
# Iteration 21, loss = 0.23621088
# Iteration 22, loss = 0.23106092
# Iteration 23, loss = 0.24316861
# Iteration 24, loss = 0.24495445
# Iteration 25, loss = 0.22495985
# Iteration 26, loss = 0.23582966
# Iteration 27, loss = 0.21577379
# Iteration 28, loss = 0.22012118
# Iteration 29, loss = 0.25356682
# Iteration 30, loss = 0.22721715
# Iteration 31, loss = 0.25146273
# Iteration 32, loss = 0.25026965
# Iteration 33, loss = 0.24453965
# Iteration 34, loss = 0.28361819
# Iteration 35, loss = 0.27089686
# Iteration 36, loss = 0.22625936
# Iteration 37, loss = 0.21760499
# Iteration 38, loss = 0.21676128
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.21192852
# Iteration 2, loss = 0.68013953
# Iteration 3, loss = 0.43339631
# Iteration 4, loss = 0.41088367
# Iteration 5, loss = 0.37355110
# Iteration 6, loss = 0.35146783
# Iteration 7, loss = 0.34069513
# Iteration 8, loss = 0.30735740
# Iteration 9, loss = 0.31069625
# Iteration 10, loss = 0.32475926
# Iteration 11, loss = 0.28530521
# Iteration 12, loss = 0.27716137
# Iteration 13, loss = 0.27751791
# Iteration 14, loss = 0.26769217
# Iteration 15, loss = 0.25704841
# Iteration 16, loss = 0.24877351
# Iteration 17, loss = 0.26567890
# Iteration 18, loss = 0.25823622
# Iteration 19, loss = 0.25455861
# Iteration 20, loss = 0.24700130
# Iteration 21, loss = 0.25716402
# Iteration 22, loss = 0.24944753
# Iteration 23, loss = 0.27714673
# Iteration 24, loss = 0.24924171
# Iteration 25, loss = 0.27313340
# Iteration 26, loss = 0.24586719
# Iteration 27, loss = 0.23854465
# Iteration 28, loss = 0.25466613
# Iteration 29, loss = 0.24222295
# Iteration 30, loss = 0.23894952
# Iteration 31, loss = 0.24545389
# Iteration 32, loss = 0.23988387
# Iteration 33, loss = 0.22707375
# Iteration 34, loss = 0.23551925
# Iteration 35, loss = 0.24371337
# Iteration 36, loss = 0.23808508
# Iteration 37, loss = 0.22667156
# Iteration 38, loss = 0.23363551
# Iteration 39, loss = 0.23731644
# Iteration 40, loss = 0.24652432
# Iteration 41, loss = 0.24609268
# Iteration 42, loss = 0.23968511
# Iteration 43, loss = 0.24598245
# Iteration 44, loss = 0.24170983
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.16182081
# Iteration 2, loss = 0.63091355
# Iteration 3, loss = 0.40753618
# Iteration 4, loss = 0.35538803
# Iteration 5, loss = 0.33694507
# Iteration 6, loss = 0.32135730
# Iteration 7, loss = 0.30481008
# Iteration 8, loss = 0.26938902
# Iteration 9, loss = 0.29957768
# Iteration 10, loss = 0.31374477
# Iteration 11, loss = 0.29684323
# Iteration 12, loss = 0.24771261
# Iteration 13, loss = 0.26335865
# Iteration 14, loss = 0.25638934
# Iteration 15, loss = 0.27215624
# Iteration 16, loss = 0.26039978
# Iteration 17, loss = 0.27074472
# Iteration 18, loss = 0.25769056
# Iteration 19, loss = 0.26275120
# Iteration 20, loss = 0.26947009
# Iteration 21, loss = 0.27905186
# Iteration 22, loss = 0.24382702
# Iteration 23, loss = 0.25480538
# Iteration 24, loss = 0.25999885
# Iteration 25, loss = 0.23799996
# Iteration 26, loss = 0.26400476
# Iteration 27, loss = 0.31932216
# Iteration 28, loss = 0.28306390
# Iteration 29, loss = 0.24691037
# Iteration 30, loss = 0.24372204
# Iteration 31, loss = 0.24444925
# Iteration 32, loss = 0.22675374
# Iteration 33, loss = 0.25246355
# Iteration 34, loss = 0.23612075
# Iteration 35, loss = 0.21885300
# Iteration 36, loss = 0.22096132
# Iteration 37, loss = 0.23223291
# Iteration 38, loss = 0.24066215
# Iteration 39, loss = 0.24096357
# Iteration 40, loss = 0.23356936
# Iteration 41, loss = 0.23354560
# Iteration 42, loss = 0.25066445
# Iteration 43, loss = 0.26471459
# Iteration 44, loss = 0.23888311
# Iteration 45, loss = 0.22795859
# Iteration 46, loss = 0.23300392
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.18139600
# Iteration 2, loss = 0.69614284
# Iteration 3, loss = 0.39883357
# Iteration 4, loss = 0.34565321
# Iteration 5, loss = 0.31213005
# Iteration 6, loss = 0.30615261
# Iteration 7, loss = 0.32170408
# Iteration 8, loss = 0.27668550
# Iteration 9, loss = 0.30811079
# Iteration 10, loss = 0.30245844
# Iteration 11, loss = 0.28468501
# Iteration 12, loss = 0.27605857
# Iteration 13, loss = 0.26673138
# Iteration 14, loss = 0.29770617
# Iteration 15, loss = 0.32340147
# Iteration 16, loss = 0.25754766
# Iteration 17, loss = 0.26211012
# Iteration 18, loss = 0.28213278
# Iteration 19, loss = 0.25654898
# Iteration 20, loss = 0.25142610
# Iteration 21, loss = 0.27556865
# Iteration 22, loss = 0.25484144
# Iteration 23, loss = 0.28169532
# Iteration 24, loss = 0.26469644
# Iteration 25, loss = 0.25820495
# Iteration 26, loss = 0.26583276
# Iteration 27, loss = 0.27339058
# Iteration 28, loss = 0.25643917
# Iteration 29, loss = 0.26677793
# Iteration 30, loss = 0.25081318
# Iteration 31, loss = 0.25576911
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.16158550
# Iteration 2, loss = 0.63803009
# Iteration 3, loss = 0.40711587
# Iteration 4, loss = 0.37511301
# Iteration 5, loss = 0.33562941
# Iteration 6, loss = 0.31694823
# Iteration 7, loss = 0.30829808
# Iteration 8, loss = 0.29843474
# Iteration 9, loss = 0.30957919
# Iteration 10, loss = 0.29192412
# Iteration 11, loss = 0.31308058
# Iteration 12, loss = 0.29089037
# Iteration 13, loss = 0.26578495
# Iteration 14, loss = 0.27144166
# Iteration 15, loss = 0.26994542
# Iteration 16, loss = 0.26967406
# Iteration 17, loss = 0.25022000
# Iteration 18, loss = 0.25715473
# Iteration 19, loss = 0.26198396
# Iteration 20, loss = 0.28405518
# Iteration 21, loss = 0.27262219
# Iteration 22, loss = 0.28669852
# Iteration 23, loss = 0.25985573
# Iteration 24, loss = 0.27729742
# Iteration 25, loss = 0.25799218
# Iteration 26, loss = 0.25102397
# Iteration 27, loss = 0.28057210
# Iteration 28, loss = 0.27216652
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.17725931
# Iteration 2, loss = 0.68287346
# Iteration 3, loss = 0.45597977
# Iteration 4, loss = 0.41120337
# Iteration 5, loss = 0.36284475
# Iteration 6, loss = 0.36781983
# Iteration 7, loss = 0.34948156
# Iteration 8, loss = 0.32709397
# Iteration 9, loss = 0.33135415
# Iteration 10, loss = 0.29221022
# Iteration 11, loss = 0.29406666
# Iteration 12, loss = 0.28201678
# Iteration 13, loss = 0.29268049
# Iteration 14, loss = 0.26785647
# Iteration 15, loss = 0.26161740
# Iteration 16, loss = 0.25914502
# Iteration 17, loss = 0.25464945
# Iteration 18, loss = 0.27982217
# Iteration 19, loss = 0.28120931
# Iteration 20, loss = 0.28876581
# Iteration 21, loss = 0.27845265
# Iteration 22, loss = 0.25681990
# Iteration 23, loss = 0.26761116
# Iteration 24, loss = 0.24973318
# Iteration 25, loss = 0.24972364
# Iteration 26, loss = 0.25813814
# Iteration 27, loss = 0.25463847
# Iteration 28, loss = 0.25252031
# Iteration 29, loss = 0.23948042
# Iteration 30, loss = 0.23824214
# Iteration 31, loss = 0.23759851
# Iteration 32, loss = 0.25916603
# Iteration 33, loss = 0.25084561
# Iteration 34, loss = 0.23180557
# Iteration 35, loss = 0.23394068
# Iteration 36, loss = 0.23175597
# Iteration 37, loss = 0.22766671
# Iteration 38, loss = 0.25151053
# Iteration 39, loss = 0.26607378
# Iteration 40, loss = 0.24146672
# Iteration 41, loss = 0.24682175
# Iteration 42, loss = 0.25234672
# Iteration 43, loss = 0.22498298
# Iteration 44, loss = 0.22023411
# Iteration 45, loss = 0.22309251
# Iteration 46, loss = 0.22046995
# Iteration 47, loss = 0.23989397
# Iteration 48, loss = 0.22112018
# Iteration 49, loss = 0.25437025
# Iteration 50, loss = 0.21854872
# Iteration 51, loss = 0.22266266
# Iteration 52, loss = 0.22711549
# Iteration 53, loss = 0.25357318
# Iteration 54, loss = 0.25129214
# Iteration 55, loss = 0.25847138
# Iteration 56, loss = 0.25323696
# Iteration 57, loss = 0.27790286
# Iteration 58, loss = 0.25453407
# Iteration 59, loss = 0.23453547
# Iteration 60, loss = 0.22516436
# Iteration 61, loss = 0.21812819
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.18532783
# Iteration 2, loss = 0.62504106
# Iteration 3, loss = 0.42635567
# Iteration 4, loss = 0.39493277
# Iteration 5, loss = 0.38081712
# Iteration 6, loss = 0.37058467
# Iteration 7, loss = 0.38025785
# Iteration 8, loss = 0.35277815
# Iteration 9, loss = 0.35781211
# Iteration 10, loss = 0.35694876
# Iteration 11, loss = 0.35788489
# Iteration 12, loss = 0.31770433
# Iteration 13, loss = 0.31299419
# Iteration 14, loss = 0.30392545
# Iteration 15, loss = 0.29006736
# Iteration 16, loss = 0.31318735
# Iteration 17, loss = 0.29336960
# Iteration 18, loss = 0.28009927
# Iteration 19, loss = 0.28509138
# Iteration 20, loss = 0.29214740
# Iteration 21, loss = 0.26972107
# Iteration 22, loss = 0.28982749
# Iteration 23, loss = 0.26783373
# Iteration 24, loss = 0.26886011
# Iteration 25, loss = 0.26362139
# Iteration 26, loss = 0.25516756
# Iteration 27, loss = 0.27318544
# Iteration 28, loss = 0.27109906
# Iteration 29, loss = 0.25885826
# Iteration 30, loss = 0.24155820
# Iteration 31, loss = 0.26190116
# Iteration 32, loss = 0.27032853
# Iteration 33, loss = 0.26460994
# Iteration 34, loss = 0.26130039
# Iteration 35, loss = 0.26046648
# Iteration 36, loss = 0.25203282
# Iteration 37, loss = 0.24529152
# Iteration 38, loss = 0.24343471
# Iteration 39, loss = 0.24714342
# Iteration 40, loss = 0.24968557
# Iteration 41, loss = 0.25872426
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.16926524
# Iteration 2, loss = 0.60136624
# Iteration 3, loss = 0.40548378
# Iteration 4, loss = 0.36830478
# Iteration 5, loss = 0.35270487
# Iteration 6, loss = 0.34254168
# Iteration 7, loss = 0.31704466
# Iteration 8, loss = 0.31123978
# Iteration 9, loss = 0.30330155
# Iteration 10, loss = 0.28486812
# Iteration 11, loss = 0.28115353
# Iteration 12, loss = 0.28858209
# Iteration 13, loss = 0.26982245
# Iteration 14, loss = 0.26384229
# Iteration 15, loss = 0.25363802
# Iteration 16, loss = 0.26509712
# Iteration 17, loss = 0.26348568
# Iteration 18, loss = 0.25839773
# Iteration 19, loss = 0.26941989
# Iteration 20, loss = 0.26205207
# Iteration 21, loss = 0.28320840
# Iteration 22, loss = 0.26363082
# Iteration 23, loss = 0.23921807
# Iteration 24, loss = 0.26516137
# Iteration 25, loss = 0.25351661
# Iteration 26, loss = 0.23717989
# Iteration 27, loss = 0.22886352
# Iteration 28, loss = 0.23868439
# Iteration 29, loss = 0.23926242
# Iteration 30, loss = 0.25319866
# Iteration 31, loss = 0.25396901
# Iteration 32, loss = 0.26315437
# Iteration 33, loss = 0.24081389
# Iteration 34, loss = 0.24914827
# Iteration 35, loss = 0.23527008
# Iteration 36, loss = 0.22583641
# Iteration 37, loss = 0.24692894
# Iteration 38, loss = 0.24578257
# Iteration 39, loss = 0.24761390
# Iteration 40, loss = 0.22900027
# Iteration 41, loss = 0.22957594
# Iteration 42, loss = 0.22304196
# Iteration 43, loss = 0.24546494
# Iteration 44, loss = 0.24270342
# Iteration 45, loss = 0.22790738
# Iteration 46, loss = 0.21616338
# Iteration 47, loss = 0.21628292
# Iteration 48, loss = 0.20973902
# Iteration 49, loss = 0.21986577
# Iteration 50, loss = 0.23178174
# Iteration 51, loss = 0.22629193
# Iteration 52, loss = 0.28540183
# Iteration 53, loss = 0.24716729
# Iteration 54, loss = 0.22366079
# Iteration 55, loss = 0.22940919
# Iteration 56, loss = 0.21420197
# Iteration 57, loss = 0.22172244
# Iteration 58, loss = 0.21343648
# Iteration 59, loss = 0.23597020
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 1.16708985
# Iteration 2, loss = 0.66869999
# Iteration 3, loss = 0.39002733
# Iteration 4, loss = 0.34984987
# Iteration 5, loss = 0.29860121
# Iteration 6, loss = 0.26903932
# Iteration 7, loss = 0.29123219
# Iteration 8, loss = 0.27918773
# Iteration 9, loss = 0.26074840
# Iteration 10, loss = 0.24840415
# Iteration 11, loss = 0.24570934
# Iteration 12, loss = 0.26394717
# Iteration 13, loss = 0.23893280
# Iteration 14, loss = 0.23497199
# Iteration 15, loss = 0.21047631
# Iteration 16, loss = 0.23666463
# Iteration 17, loss = 0.24201643
# Iteration 18, loss = 0.24264893
# Iteration 19, loss = 0.22365474
# Iteration 20, loss = 0.22356158
# Iteration 21, loss = 0.22626248
# Iteration 22, loss = 0.22320420
# Iteration 23, loss = 0.22485192
# Iteration 24, loss = 0.23926534
# Iteration 25, loss = 0.25033296
# Iteration 26, loss = 0.24695853
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# Experimento 12
# Acurácia Média: 88.28%
# Precisão Média: 90.75%
# Revocação Média: 89.57%
# F1-Score Médio: 88.91%
