# %% [markdown]
# Experimento 15 - Linear Interpolation Imputation, MAD outlier detection, Z-Score normalization, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               668
# Perimeter          690
# MajorAxisLength    682
# MinorAxisLength    653
# AspectRatio        659
# Eccentricity       689
# ConvexArea         679
# EquivDiameter      729
# Extent             704
# Solidity           665
# Roundness          644
# Compactness        674
# ShapeFactor1       716
# ShapeFactor2       684
# ShapeFactor3       677
# ShapeFactor4       664
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0        NaN       288.721612       185.944705     1.552728
# 13607  42101.0        NaN       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904       NaN  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932       NaN   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681           NaN      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with Linear Interpolation
df_imputed = df.interpolate(method="nearest", order=3, limit=None,
                            limit_direction='both').ffill().bfill()
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    760.701       288.721612       185.944705     1.552728
# 13607  42101.0    759.321       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.783968  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.990752   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001886      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with MAD
from scipy import stats

print(f'Pre Outlier Shape: {df_imputed.shape}')

df_no_outliers = df_imputed.copy()
print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      mad = 1.4826 * np.median(np.absolute(class_unique[feature] - class_unique[feature].median()))
      upper = class_unique[feature].median() + (3 * mad)
      lower = class_unique[feature].median() - (3 * mad)
      excluded_lower = pd.Series(class_unique[class_unique[feature] < lower].index)
      excluded_upper = pd.Series(class_unique[class_unique[feature] > upper].index)
      df_no_outliers.drop(excluded_lower.values, inplace = True, errors='ignore')
      df_no_outliers.drop(excluded_upper.values, inplace = True, errors='ignore')




print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
# Pos Outlier Shape: (12130, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1190  1190      1190            1190            1190        1190
# BOMBAY     470   470       470             470             470         470
# CALI      1506  1506      1506            1506            1506        1506
# DERMASON  3194  3194      3194            3194            3194        3194
# HOROZ     1618  1618      1618            1618            1618        1618
# SEKER     1757  1757      1757            1757            1757        1757
# SIRA      2395  2395      2395            2395            2395        2395
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1190       1190          1190   1190     1190      1190
# BOMBAY            470        470           470    470      470       470
# CALI             1506       1506          1506   1506     1506      1506
# DERMASON         3194       3194          3194   3194     3194      3194
# HOROZ            1618       1618          1618   1618     1618      1618
# SEKER            1757       1757          1757   1757     1757      1757
# SIRA             2395       2395          2395   2395     2395      2395
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1190         1190         1190         1190         1190
# BOMBAY           470          470          470          470          470
# CALI            1506         1506         1506         1506         1506
# DERMASON        3194         3194         3194         3194         3194
# HOROZ           1618         1618         1618         1618         1618
# SEKER           1757         1757         1757         1757         1757
# SIRA            2395         2395         2395         2395         2395

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      29380.0    624.110       212.826130       175.931143     1.209713
# 2      30279.0    634.927       212.560556       181.510182     1.171067
# 3      30519.0    629.727       212.996755       182.737204     1.165591
# 4      30685.0    635.681       213.534145       183.157146     1.165852
# ...        ...        ...              ...              ...          ...
# 12125  42097.0    760.701       288.721612       185.944705     1.552728
# 12126  42101.0    759.321       281.576392       190.713136     1.476439
# 12127  42139.0    759.321       281.539928       191.187979     1.472582
# 12128  42147.0    763.779       283.382636       190.275731     1.489326
# 12129  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.562727     29690.0     193.410904  0.783968  0.989559   0.947849
# 2          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 3          0.513760     30847.0     197.124320  0.770682  0.989367   0.967109
# 4          0.514081     31044.0     197.124320  0.771561  0.988436   0.954240
# ...             ...         ...            ...       ...       ...        ...
# 12125      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 12126      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 12127      0.734065     42569.0     231.631261  0.729932  0.990752   0.918424
# 12128      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 12129      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.908774      0.007244      0.003048      0.825871      0.999066
# 2         0.923726      0.007020      0.003153      0.853270      0.999236
# 3         0.925480      0.006979      0.003158      0.856514      0.998345
# 4         0.925658      0.006959      0.003152      0.856844      0.998953
# ...            ...           ...           ...           ...           ...
# 12125     0.801865      0.006858      0.001749      0.642988      0.998385
# 12126     0.822252      0.006688      0.001886      0.676099      0.998219
# 12127     0.822730      0.006681      0.001886      0.676884      0.996767
# 12128     0.817457      0.006724      0.001852      0.668237      0.995222
# 12129     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12125  DERMASON
# 12126  DERMASON
# 12127  DERMASON
# 12128  DERMASON
# 12129  DERMASON
#
# [12130 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.848881  -1.145443        -1.315486        -0.638905    -1.575082
# 1     -0.815161  -1.080759        -1.261079        -0.593250    -1.523979
# 2     -0.784386  -1.030128        -1.264188        -0.468536    -1.681705
# 3     -0.776170  -1.054468        -1.259082        -0.441108    -1.704055
# 4     -0.770487  -1.026598        -1.252791        -0.431720    -1.702988
# ...         ...        ...              ...              ...          ...
# 12125 -0.379817  -0.441412        -0.372690        -0.369407    -0.124023
# 12126 -0.379680  -0.447871        -0.456328        -0.262814    -0.435382
# 12127 -0.378379  -0.447871        -0.456755        -0.252200    -0.451126
# 12128 -0.378105  -0.427004        -0.435185        -0.272592    -0.382787
# 12129 -0.377694  -0.387415        -0.297528        -0.453011     0.149887
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.246666   -0.849160      -1.072744  0.260353  0.305658   1.430078
# 1         -2.102861   -0.816257      -1.017347  0.672221  0.508349   1.251272
# 2         -2.574152   -0.785547      -0.967591  0.502103  0.494225   1.181039
# 3         -2.648098   -0.777211      -0.954434  0.399233  0.453003   1.589637
# 4         -2.644520   -0.770563      -0.954434  0.417307  0.184458   1.363540
# ...             ...         ...            ...       ...       ...        ...
# 12125      0.149392   -0.383684      -0.371771 -0.753582  0.731138   0.702321
# 12126     -0.176852   -0.384157      -0.371584  1.000449  0.852388   0.797406
# 12127     -0.195084   -0.381626      -0.369814 -0.438025  0.852388   0.734313
# 12128     -0.117253   -0.378318      -0.369442 -0.942305  0.004725   0.549534
# 12129      0.390911   -0.380579      -0.368883  0.774838  0.534051   0.206490
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         1.864218      0.704173      2.431736      1.952993      0.958894
# 1         1.788855      0.625525      2.262988      1.867366      1.063303
# 2         2.034693      0.424540      2.441042      2.148275      1.115056
# 3         2.063540      0.387805      2.450375      2.181537      0.843173
# 4         2.066469      0.369630      2.438959      2.184917      1.028783
# ...            ...           ...           ...           ...           ...
# 12125     0.031040      0.279461      0.061774     -0.007643      0.855586
# 12126     0.366246      0.126493      0.293552      0.331827      0.804764
# 12127     0.374098      0.120301      0.293552      0.339881      0.361992
# 12128     0.287411      0.158418      0.236244      0.251222     -0.109289
# 12129    -0.246306      0.407157     -0.123460     -0.282073      0.792857
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12125  DERMASON
# 12126  DERMASON
# 12127  DERMASON
# 12128  DERMASON
# 12129  DERMASON
#
# [12130 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}

y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 15')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 15
# Acurácia Média: 91.74%
# Precisão Média: 94.47%
# Revocação Média: 93.37%
# F1-Score Médio: 93.12%
