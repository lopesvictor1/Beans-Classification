# %% [markdown]
# Experimento 9 - Linear Interpolation Imputer, 3sigma, min max normalization, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               666
# Perimeter          656
# MajorAxisLength    654
# MinorAxisLength    631
# AspectRatio        693
# Eccentricity       652
# ConvexArea         674
# EquivDiameter      689
# Extent             680
# Solidity           634
# Roundness          665
# Compactness        713
# ShapeFactor1       641
# ShapeFactor2       609
# ShapeFactor3       672
# ShapeFactor4       725
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291              NaN       173.888747     1.197191
# 1          NaN    638.018       200.524796              NaN     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612              NaN     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610      NaN    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0            NaN  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574       NaN   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962       NaN   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851           NaN
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888           NaN      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237           NaN
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with Linear Interpolation
df_imputed = df.interpolate(method="nearest", order=3, limit=None,
                            limit_direction='both').ffill().bfill()
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       200.524796       173.888747     1.197191
# 1      28395.0    638.018       200.524796       173.888747     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       193.945367     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42147.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     193.410904  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990862   0.916603
# 13607      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.987813   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998724
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676099      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.996767
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with 3sigma
from scipy import stats


print(f'Pre Outlier Shape: {df_imputed.shape}')
df_no_outliers = df_imputed.copy()

print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      upper = class_unique[feature].mean() + (3 * class_unique[feature].std())
      lower = class_unique[feature].mean() - (3 * class_unique[feature].std())
      excluded = pd.Series(class_unique[class_unique[feature] < lower].index)
      #print(excluded.values)
      df_no_outliers.drop(excluded.values, inplace = True, errors='ignore')

print(df_no_outliers.groupby('Class').count())
print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# Class
# 0      1264       1264             1264             1264         1264
# 1       497        497              497              497          497
# 2      1581       1581             1581             1581         1581
# 3      3410       3410             3410             3410         3410
# 4      1806       1806             1806             1806         1806
# 5      1918       1918             1918             1918         1918
# 6      2537       2537             2537             2537         2537
#
#        Eccentricity  ConvexArea  EquivDiameter  Extent  Solidity  Roundness  \
# Class
# 0              1264        1264           1264    1264      1264       1264
# 1               497         497            497     497       497        497
# 2              1581        1581           1581    1581      1581       1581
# 3              3410        3410           3410    3410      3410       3410
# 4              1806        1806           1806    1806      1806       1806
# 5              1918        1918           1918    1918      1918       1918
# 6              2537        2537           2537    2537      2537       2537
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# Class
# 0             1264          1264          1264          1264          1264
# 1              497           497           497           497           497
# 2             1581          1581          1581          1581          1581
# 3             3410          3410          3410          3410          3410
# 4             1806          1806          1806          1806          1806
# 5             1918          1918          1918          1918          1918
# 6             2537          2537          2537          2537          2537
# Pos Outlier Shape: (13013, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1264  1264      1264            1264            1264        1264
# BOMBAY     497   497       497             497             497         497
# CALI      1581  1581      1581            1581            1581        1581
# DERMASON  3410  3410      3410            3410            3410        3410
# HOROZ     1806  1806      1806            1806            1806        1806
# SEKER     1918  1918      1918            1918            1918        1918
# SIRA      2537  2537      2537            2537            2537        2537
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1264       1264          1264   1264     1264      1264
# BOMBAY            497        497           497    497      497       497
# CALI             1581       1581          1581   1581     1581      1581
# DERMASON         3410       3410          3410   3410     3410      3410
# HOROZ            1806       1806          1806   1806     1806      1806
# SEKER            1918       1918          1918   1918     1918      1918
# SIRA             2537       2537          2537   2537     2537      2537
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1264         1264         1264         1264         1264
# BOMBAY           497          497          497          497          497
# CALI            1581         1581         1581         1581         1581
# DERMASON        3410         3410         3410         3410         3410
# HOROZ           1806         1806         1806         1806         1806
# SEKER           1918         1918         1918         1918         1918
# SIRA            2537         2537         2537         2537         2537

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       200.524796       173.888747     1.197191
# 1      28395.0    638.018       200.524796       173.888747     1.097356
# 2      29380.0    624.110       212.826130       175.931143     1.209713
# 3      30279.0    634.927       201.847882       181.510182     1.171067
# 4      30477.0    670.033       211.050155       184.039050     1.171067
# ...        ...        ...              ...              ...          ...
# 13008  42097.0    759.696       288.721612       193.945367     1.552728
# 13009  42101.0    757.499       281.576392       190.713136     1.476439
# 13010  42139.0    759.321       281.539928       191.187979     1.472582
# 13011  42147.0    763.779       283.382636       190.275731     1.489326
# 13012  42147.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.520401     30600.0     196.347702  0.775688  0.989510   0.943852
# 4          0.489478     30970.0     196.988633  0.762402  0.984081   0.853080
# ...             ...         ...            ...       ...       ...        ...
# 13008      0.765002     42508.0     231.515799  0.714574  0.990862   0.916603
# 13009      0.735702     42494.0     231.526798  0.799943  0.990752   0.922015
# 13010      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13011      0.741055     42667.0     231.653247  0.705389  0.987813   0.907906
# 13012      0.786693     42600.0     231.686223  0.788962  0.987813   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998724
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.923726      0.007020      0.003153      0.853270      0.999236
# 4         0.933374      0.006925      0.003242      0.871186      0.999049
# ...            ...           ...           ...           ...           ...
# 13008     0.801865      0.006858      0.001749      0.642988      0.998385
# 13009     0.822252      0.006688      0.001886      0.676099      0.998219
# 13010     0.822730      0.006681      0.001888      0.676099      0.996767
# 13011     0.817457      0.006724      0.001852      0.668237      0.996767
# 13012     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13008  DERMASON
# 13009  DERMASON
# 13010  DERMASON
# 13011  DERMASON
# 13012  DERMASON
#
# [13013 rows x 17 columns]

# %%
#Normalization with min max
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      0.034338   0.060789         0.027395         0.134028     0.095588
# 1      0.034338   0.080647         0.027395         0.134028     0.022366
# 2      0.038603   0.070686         0.049649         0.140205     0.104772
# 3      0.042495   0.078433         0.029788         0.157079     0.076428
# 4      0.043352   0.103576         0.046436         0.164728     0.076428
# ...         ...        ...              ...              ...          ...
# 13008  0.093662   0.167792         0.186951         0.194691     0.356352
# 13009  0.093680   0.166218         0.174025         0.184915     0.300399
# 13010  0.093844   0.167523         0.173959         0.186351     0.297570
# 13011  0.093879   0.170716         0.177293         0.183592     0.309851
# 13012  0.093879   0.176774         0.198568         0.159180     0.405575
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.325651    0.033564       0.071030  0.671024  0.784707   0.902572
# 1          0.068251    0.035495       0.073829  0.735504  0.641570   0.690782
# 2          0.349735    0.037684       0.079116  0.716671  0.810697   0.872210
# 3          0.270803    0.041529       0.086379  0.708871  0.808886   0.860284
# 4          0.213136    0.043093       0.087964  0.666131  0.608130   0.589489
# ...             ...         ...            ...       ...       ...        ...
# 13008      0.726947    0.091848       0.173345  0.512286  0.858877   0.778995
# 13009      0.672307    0.091788       0.173373  0.786890  0.854812   0.795141
# 13010      0.669254    0.092105       0.173631  0.561689  0.823270   0.784427
# 13011      0.682289    0.092519       0.173685  0.482741  0.746119   0.753050
# 13012      0.767398    0.092236       0.173767  0.751569  0.746119   0.694799
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.799864      0.635649      0.861196      0.766209      0.961646
# 1         0.918629      0.585538      1.000000      0.902914      0.961646
# 2         0.786424      0.623209      0.828005      0.751113      0.974660
# 3         0.830266      0.591419      0.863027      0.800639      0.981111
# 4         0.858555      0.577903      0.892778      0.833025      0.973999
# ...            ...           ...           ...           ...           ...
# 13008     0.472939      0.568471      0.395047      0.420535      0.948770
# 13009     0.532719      0.544275      0.440635      0.480386      0.942435
# 13010     0.534119      0.543296      0.441448      0.480386      0.887246
# 13011     0.518659      0.549325      0.429363      0.466175      0.887246
# 13012     0.423478      0.588669      0.358613      0.372151      0.940951
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13008  DERMASON
# 13009  DERMASON
# 13010  DERMASON
# 13011  DERMASON
# 13012  DERMASON
#
# [13013 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}

y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 9')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 9
# Acurácia Média: 91.04%
# Precisão Média: 93.81%
# Revocação Média: 92.60%
# F1-Score Médio: 92.40%
