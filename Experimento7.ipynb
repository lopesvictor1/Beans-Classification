# %% [markdown]
# Experimento 7 - KNN Imputer, MAD outlier detection, Z-Score normalization, knn classifier

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import seaborn.objects as so
from ucimlrepo import fetch_ucirepo

# %%
beans = fetch_ucirepo(id=602)
df = beans.data.features
targets = beans.data.targets

# %%
cols = ['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength', 'AspectRatio', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent', 'Solidity', 'Roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2', 'ShapeFactor3', 'ShapeFactor4']

# %%
import random

#Introducing Missing values (5%)

for index, i in enumerate(df):
  for jndex, j in enumerate(df[i]):
    if random.randint(0,100) < 5:
      df.loc[jndex,i] = np.NaN

# %%
df.isna().sum()
# Out:
# Area               684
# Perimeter          685
# MajorAxisLength    710
# MinorAxisLength    694
# AspectRatio        679
# Eccentricity       721
# ConvexArea         696
# EquivDiameter      654
# Extent             694
# Solidity           681
# Roundness          676
# Compactness        691
# ShapeFactor1       672
# ShapeFactor2       690
# ShapeFactor3       709
# ShapeFactor4       710
# dtype: int64

# %%
df
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0    610.291       208.178117       173.888747     1.197191
# 1      28734.0    638.018       200.524796       182.734419     1.097356
# 2      29380.0        NaN       212.826130       175.931143     1.209713
# 3      30008.0    645.884       210.557999       182.516516     1.153638
# 4      30140.0    620.134       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0    759.696       288.721612       185.944705     1.552728
# 13607  42101.0    757.499       281.576392       190.713136     1.476439
# 13608  42139.0    759.321       281.539928       191.187979     1.472582
# 13609  42147.0    763.779       283.382636       190.275731     1.489326
# 13610  42159.0    772.237       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798       NaN  0.990752        NaN
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247       NaN  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252           NaN      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724           NaN      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#Imputing Missing Values with KNN Imputer
from sklearn.impute import KNNImputer as knni

imputer = knni(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns = df.columns)
df_imputed
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0   610.2910       208.178117       173.888747     1.197191
# 1      28734.0   638.0180       200.524796       182.734419     1.097356
# 2      29380.0   630.0354       212.826130       175.931143     1.209713
# 3      30008.0   645.8840       210.557999       182.516516     1.153638
# 4      30140.0   620.1340       201.847882       190.279279     1.060798
# ...        ...        ...              ...              ...          ...
# 13606  42097.0   759.6960       288.721612       185.944705     1.552728
# 13607  42101.0   757.4990       281.576392       190.713136     1.476439
# 13608  42139.0   759.3210       281.539928       191.187979     1.472582
# 13609  42147.0   763.7790       283.382636       190.275731     1.489326
# 13610  42159.0   772.2370       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.411785     29172.0     191.272751  0.783968  0.984986   0.887034
# 2          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 3          0.498616     30724.0     195.467062  0.782681  0.976696   0.903936
# 4          0.333680     30417.0     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702     42494.0     231.526798  0.755470  0.990752   0.907717
# 13608      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055     42667.0     231.653247  0.751975  0.987813   0.907906
# 13610      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006807      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001809      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
# [13611 rows x 16 columns]

# %%
#adding the labels
df_imputed['Class'] = targets
df_pre_missing_values = df.copy()
print(df_imputed.groupby('Class').agg(['count']))
df_imputed['Class'] = df_imputed['Class'].transform(lambda x: 0 if x == 'BARBUNYA' else (1 if x == 'BOMBAY' else (2 if x == 'CALI' else (3 if x == 'DERMASON' else (4 if x == 'HOROZ' else (5 if x == 'SEKER' else 6))))))
# Out:
#           Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count     count           count           count       count
# Class
# BARBUNYA  1322      1322            1322            1322        1322
# BOMBAY     522       522             522             522         522
# CALI      1630      1630            1630            1630        1630
# DERMASON  3546      3546            3546            3546        3546
# HOROZ     1928      1928            1928            1928        1928
# SEKER     2027      2027            2027            2027        2027
# SIRA      2636      2636            2636            2636        2636
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1322       1322          1322   1322     1322      1322
# BOMBAY            522        522           522    522      522       522
# CALI             1630       1630          1630   1630     1630      1630
# DERMASON         3546       3546          3546   3546     3546      3546
# HOROZ            1928       1928          1928   1928     1928      1928
# SEKER            2027       2027          2027   2027     2027      2027
# SIRA             2636       2636          2636   2636     2636      2636
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1322         1322         1322         1322         1322
# BOMBAY           522          522          522          522          522
# CALI            1630         1630         1630         1630         1630
# DERMASON        3546         3546         3546         3546         3546
# HOROZ           1928         1928         1928         1928         1928
# SEKER           2027         2027         2027         2027         2027
# SIRA            2636         2636         2636         2636         2636

# %%
#Outlier Removal with MAD
from scipy import stats

print(f'Pre Outlier Shape: {df_imputed.shape}')

df_no_outliers = df_imputed.copy()
print(df_no_outliers['Class'].unique())
for i in df_no_outliers['Class'].unique():
    class_unique = df_no_outliers[df_no_outliers['Class'] == i]
    for feature in class_unique:
      mad = 1.4826 * np.median(np.absolute(class_unique[feature] - class_unique[feature].median()))
      upper = class_unique[feature].median() + (3 * mad)
      lower = class_unique[feature].median() - (3 * mad)
      excluded_lower = pd.Series(class_unique[class_unique[feature] < lower].index)
      excluded_upper = pd.Series(class_unique[class_unique[feature] > upper].index)
      df_no_outliers.drop(excluded_lower.values, inplace = True, errors='ignore')
      df_no_outliers.drop(excluded_upper.values, inplace = True, errors='ignore')


print(f'Pos Outlier Shape: {df_no_outliers.shape}')
# Out:
# Pre Outlier Shape: (13611, 17)
# [5 0 1 2 4 6 3]
# Pos Outlier Shape: (12086, 17)

# %%
df_no_outliers['Class'] = df_no_outliers['Class'].transform(lambda x: 'BARBUNYA' if x == 0 else ('BOMBAY' if x == 1 else ('CALI' if x == 2 else ('DERMASON' if x == 3 else ('HOROZ' if x == 4 else ('SEKER' if x == 5 else 'SIRA'))))))
df_no_outliers = df_no_outliers.reset_index()
print(df_no_outliers.groupby('Class').agg(['count']))
# Out:
#          index  Area Perimeter MajorAxisLength MinorAxisLength AspectRatio  \
#          count count     count           count           count       count
# Class
# BARBUNYA  1187  1187      1187            1187            1187        1187
# BOMBAY     462   462       462             462             462         462
# CALI      1505  1505      1505            1505            1505        1505
# DERMASON  3187  3187      3187            3187            3187        3187
# HOROZ     1623  1623      1623            1623            1623        1623
# SEKER     1741  1741      1741            1741            1741        1741
# SIRA      2381  2381      2381            2381            2381        2381
#
#          Eccentricity ConvexArea EquivDiameter Extent Solidity Roundness  \
#                 count      count         count  count    count     count
# Class
# BARBUNYA         1187       1187          1187   1187     1187      1187
# BOMBAY            462        462           462    462      462       462
# CALI             1505       1505          1505   1505     1505      1505
# DERMASON         3187       3187          3187   3187     3187      3187
# HOROZ            1623       1623          1623   1623     1623      1623
# SEKER            1741       1741          1741   1741     1741      1741
# SIRA             2381       2381          2381   2381     2381      2381
#
#          Compactness ShapeFactor1 ShapeFactor2 ShapeFactor3 ShapeFactor4
#                count        count        count        count        count
# Class
# BARBUNYA        1187         1187         1187         1187         1187
# BOMBAY           462          462          462          462          462
# CALI            1505         1505         1505         1505         1505
# DERMASON        3187         3187         3187         3187         3187
# HOROZ           1623         1623         1623         1623         1623
# SEKER           1741         1741         1741         1741         1741
# SIRA            2381         2381         2381         2381         2381

# %%
df_no_outliers = df_no_outliers.drop(['index'], axis='columns')
df_no_outliers
# Out:
#           Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0      28395.0   610.2910       208.178117       173.888747     1.197191
# 1      29380.0   630.0354       212.826130       175.931143     1.209713
# 2      30519.0   629.7270       234.747801       182.737204     1.165591
# 3      30685.0   635.6810       213.534145       183.157146     1.165852
# 4      30917.0   640.7650       213.560089       184.439871     1.157885
# ...        ...        ...              ...              ...          ...
# 12081  42097.0   759.6960       288.721612       185.944705     1.552728
# 12082  42101.0   757.4990       281.576392       190.713136     1.476439
# 12083  42139.0   759.3210       281.539928       191.187979     1.472582
# 12084  42147.0   763.7790       283.382636       190.275731     1.489326
# 12085  42159.0   772.2370       295.142741       182.204716     1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0          0.549812     28715.0     190.141097  0.763923  0.988856   0.958027
# 1          0.562727     29690.0     193.410904  0.778113  0.989559   0.947849
# 2          0.513760     30847.0     197.124320  0.770682  0.989367   0.967109
# 3          0.514081     31044.0     200.483505  0.771561  0.988436   0.954240
# 4          0.504102     31280.0     198.405511  0.770805  0.988395   0.946258
# ...             ...         ...            ...       ...       ...        ...
# 12081      0.765002     42508.0     231.515799  0.714574  0.990331   0.916603
# 12082      0.735702     42494.0     231.526798  0.755470  0.990752   0.907717
# 12083      0.734065     42569.0     231.631261  0.729932  0.989899   0.918424
# 12084      0.741055     42667.0     231.653247  0.751975  0.987813   0.907906
# 12085      0.786693     42600.0     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.908774      0.007244      0.003048      0.825871      0.999066
# 2         0.925480      0.006979      0.003158      0.856514      0.998345
# 3         0.925658      0.006959      0.002455      0.856844      0.998953
# 4         0.929038      0.006908      0.003174      0.863112      0.999384
# ...            ...           ...           ...           ...           ...
# 12081     0.801865      0.006858      0.001749      0.642988      0.998385
# 12082     0.822252      0.006807      0.001886      0.676099      0.998219
# 12083     0.822730      0.006681      0.001888      0.676884      0.996767
# 12084     0.817457      0.006724      0.001809      0.668237      0.995222
# 12085     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12081  DERMASON
# 12082  DERMASON
# 12083  DERMASON
# 12084  DERMASON
# 12085  DERMASON
#
# [12086 rows x 17 columns]

# %%
#Normalization with Z-Score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit_transform(df_no_outliers[cols])
df_scaled = pd.DataFrame(scaler.transform(df_no_outliers[cols]), columns = cols)

df_scaled['Class'] = df_no_outliers['Class']
df_scaled
# Out:
#            Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRatio  \
# 0     -0.851909  -1.148828        -1.319572        -0.644312    -1.585622
# 1     -0.817996  -1.055933        -1.264886        -0.597926    -1.534251
# 2     -0.778780  -1.057384        -1.006968        -0.443352    -1.715272
# 3     -0.773065  -1.029370        -1.256556        -0.433814    -1.714198
# 4     -0.765077  -1.005451        -1.256251        -0.404682    -1.746887
# ...         ...        ...              ...              ...          ...
# 12081 -0.380152  -0.445889        -0.371942        -0.370505    -0.126954
# 12082 -0.380014  -0.456226        -0.456009        -0.262208    -0.439946
# 12083 -0.378706  -0.447653        -0.456438        -0.251424    -0.455773
# 12084 -0.378430  -0.426679        -0.434758        -0.272142    -0.387075
# 12085 -0.378017  -0.386884        -0.296395        -0.455445     0.148392
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  Roundness  \
# 0         -2.275253   -0.852960      -1.079173  0.279673  0.306562   1.436308
# 1         -2.129943   -0.819815      -1.023296  0.575607  0.513698   1.256074
# 2         -2.680886   -0.780483      -0.959840  0.420632  0.457138   1.597141
# 3         -2.677271   -0.773786      -0.902437  0.438977  0.182704   1.369239
# 4         -2.789540   -0.765763      -0.937946  0.423207  0.170730   1.227894
# ...             ...         ...            ...       ...       ...        ...
# 12081      0.145879   -0.384070      -0.372142 -0.749437  0.741371   0.702740
# 12082     -0.183779   -0.384546      -0.371954  0.103406  0.865281   0.545371
# 12083     -0.202202   -0.381997      -0.370169 -0.429157  0.613903   0.734987
# 12084     -0.123557   -0.378665      -0.369793  0.030519 -0.000970   0.548733
# 12085      0.389925   -0.380943      -0.369230  0.801858  0.539963   0.202950
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         1.878505      0.706356      2.431940      1.971915      0.969657
# 1         1.802663      0.627049      2.263185      1.885663      1.074875
# 2         2.079095      0.387337      2.450579      2.202130      0.853039
# 3         2.082042      0.369010      1.258205      2.205535      1.040087
# 4         2.137967      0.322490      2.477590      2.270274      1.172715
# ...            ...           ...           ...           ...           ...
# 12081     0.033668      0.278085      0.061889     -0.003052      0.865548
# 12082     0.371006      0.231494      0.293675      0.338899      0.814332
# 12083     0.378908      0.117592      0.297805      0.347012      0.368129
# 12084     0.291670      0.156029      0.163392      0.257705     -0.106804
# 12085    -0.245441      0.406851     -0.123353     -0.279489      0.802333
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 12081  DERMASON
# 12082  DERMASON
# 12083  DERMASON
# 12084  DERMASON
# 12085  DERMASON
#
# [12086 rows x 17 columns]

# %%
#Classification with Knn-Classification

from sklearn.neighbors import KNeighborsClassifier as knnc
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import preprocessing


classifier = knnc(n_neighbors=10)
x_train = df_scaled.iloc[:, 0:16]
y_train = df_scaled.iloc[:, 16]
scoring = {'acc' : 'accuracy',
           'prec' : 'precision_macro',
           'recall' : 'recall_macro',
           'f1' : 'f1_macro'}

y_pred = cross_validate(classifier, x_train, y_train, cv=10, scoring=scoring, return_train_score=True)


print('Experimento 7')
print('Acurácia Média: ' + '%.2f' % (np.mean(y_pred['test_acc'])*100) + '%')
print('Precisão Média: ' + '%.2f' % (np.mean(y_pred['test_prec'])*100) + '%')
print('Revocação Média: ' + '%.2f' % (np.mean(y_pred['test_recall'])*100) + '%')
print('F1-Score Médio: ' + '%.2f' % (np.mean(y_pred['test_f1'])*100) + '%')
# Out:
# Experimento 7
# Acurácia Média: 91.49%
# Precisão Média: 94.31%
# Revocação Média: 93.01%
# F1-Score Médio: 92.85%
